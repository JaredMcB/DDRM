# %% [markdown]
# # Model Reduction on a Linear SDE

# %%
include("modgen_LSDE.jl")
include("..\\..\\Tools\\Model_Reduction_Dev.jl")
# Out:
# vector_wiener_filter_fft

# %%
using JLD
using PyPlot
using DSP: nextfastfft
using Distributions
using Random

# %% [markdown]
# the model is
# $$dX_t = AX_tdt + \sigma dW_t$$
# my implementation of Euler-Maruyama produces
# $$ X_{n+1} = (1 + hA)X_n + \sqrt{h}\sigma u_n \qquad \text{where }u_n \sim N(0,1)$$

# %% [markdown]
# ## Generate the data

# %%
A = reshape([-0.5],1,1)
σ = reshape([1],1,1)
Xo = [1]
t_disc = 1000
gap = 1
scheme = "EM"

t_start = 0
t_stop  = 1e4
h       = 1e-2

Δt      = h*gap
M_out   = 20

n = 2
p = 150

Random.seed!(2020)

X = modgen_LSDE(t_start,t_stop,h,
    A = A,
    σ = σ,
    Xo = Xo,
    t_disc = t_disc,
    gap = gap)

d, N = size(X)

nfft = nextfastfft(N)
X = [X zeros(d,nfft-N)]


τ_exp, τ_int    = auto_times(X[:])*Δt
N_eff           = N*Δt/τ_int

Psi(x) = x
# Out:
# Psi (generic function with 1 method)

# %%
n = 2
p = 500
par = 55
ty = "bin"
rl = true
Preds = true
PI = false
rtol = 1e-6

nfft = 1024

@time h_wf, pred = get_wf(X, Psi;
    M_out, n, p, par, ty, nfft, rl, Preds, PI, rtol);
X = X[:,1:N]
# Out:
# Number of CKMS iterations: 149
# errK errR : 2.5978632198241732e-12 1.999792689899279e-16
#  14.610565 seconds (32.62 M allocations: 2.005 GiB, 7.71% gc time)
# 1×900001 Array{Float64,2}:
#  0.19212  0.30229  0.429609  0.505706  …  -0.944927  -0.754289  -0.72181

# %%
(τ_exp, N_eff)
# Out:
# (1.985312900169461, 4509.632473376151)

# %%
1 .+ h*A
# Out:
# 1×1 Array{Float64,2}:
#  0.995

# %%
h_wf
# Out:
# 1×1×20 Array{Float64,3}:
# [:, :, 1] =
#  0.9948222411853436
#
# [:, :, 2] =
#  -0.00023831627439697517
#
# [:, :, 3] =
#  0.00026614374924401046
#
# ...
#
# [:, :, 18] =
#  -0.000212644831026781
#
# [:, :, 19] =
#  0.00019205008599876776
#
# [:, :, 20] =
#  -0.001453737876992273

# %% [markdown]
# ## Get reduced (reproduced) model (no noise)

# %%
# d, N  = size(X)
# nu    = size(Psi(X[:,1]),1) 
# M_out = size(h_wf,3)

# X_rm = zeros(d,N); X_rm[:,1:M_out] = X[:,1:M_out]

# PSI = zeros(nu,N); 
# for i = 1:M_out
#     PSI[:,i] = Psi(X_rm[:,i])
# end

# for i = M_out + 1 : N
#     X_rm[:,i] = sum(h_wf[:,:,k]*PSI[:,i-k] for k = 1:M_out, dims = 2)
#     PSI[:,i] = Psi(X_rm[:,i])
# end

# %% [markdown]
# ## Get reduced (reproduced) model with noise

# %%
d, N  = size(X)
nu    = size(Psi(X[:,1]),1) 
M_out = 2 #size(h_wf,3)

X_rm = zeros(d,N); X_rm[:,1:M_out] = X[:,1:M_out]

PSI = zeros(nu,N); 
for i = 1:M_out
    PSI[:,i] = Psi(X_rm[:,i])
end

for i = M_out + 1 : N
    X_rm[:,i] = sum(h_wf[:,:,k]*PSI[:,i-k] for k = 1:M_out, dims = 2) + sqrt(h)*σ*randn(d)
    PSI[:,i] = Psi(X_rm[:,i])
end

# %%
X_rm
# Out:
# 1×900001 Array{Float64,2}:
#  0.19212  0.30229  0.317864  0.437519  …  -2.08802  -2.28568  -2.3026

# %%
data = Dict(
        "h_wf" => h_wf,
        "A" => A,
        "σ" => σ,
        "Xo" => Xo,
        "t_disc" => t_disc,
        "gap" => gap,
        "scheme" => scheme,
        "t_start" => t_start,
        "t_stop" => t_start,
        "h" => h,
        "X" => X,
        "X__rm" => X_rm)

save("LSDE_Data\\LSDE_wfs_M$M_out.jld",data)

# %%
data = load("LSDE_Data\\LSDE_wfs_M10.jld")
# Out:
# Dict{String,Any} with 17 entries:
#   "h"                     => 0.01
#   "_creator\\JULIA_PATCH" => 0x00000000
#   "t_disc"                => 1000
#   "X__rm_55_h_4"          => [0.207399 0.169424 … 0.854196 0.724715]
#   "t_start"               => 0
#   "σ"                     => [1]
#   "t_stop"                => 0
#   "Xo"                    => [1]
#   "scheme"                => "EM"
#   "A"                     => Complex{Float64}[1.0-0.0im, 0.994971-0.0im, 0.9899…
#   "_creator\\JULIA_MINOR" => 0x00000004
#   "_creator\\ENDIAN_BOM"  => 0x04030201
#   "h_wf"                  => [0.995123]…
#   "gap"                   => 1
#   "_creator\\WORD_SIZE"   => 64
#   "X_55"                  => [0.207399 0.169424 … 0.401593 0.241192]
#   "_creator\\JULIA_MAJOR" => 0x00000001

# %%
blup = findall(isnan,X_rm[1,:])[1]

findall(x -> x > 10^1,X_rm[1,:])[1]
# Out:
# BoundsError: attempt to access 0-element Array{Int64,1} at index [1]
#
# Stacktrace:
#  [1] getindex(::Array{Int64,1}, ::Int64) at .\array.jl:809
#  [2] top-level scope at In[15]:1
#  [3] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
plot(X[1:1000:end])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000424D49C8>

# %%
plot(X_rm[1:1000:end])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000004265BA88>

# %%
m = mean(X[1:900001])
m_rm = mean(X_rm[1:900001])
v = var(X[1:900001])
v_rm = var(X_rm[1:900001])

dist_rm = Normal(m_rm,v_rm)

f_rm(x) = pdf(dist_rm, x)

NN = 1000
XX = -5:1/NN:5
# Out:
# -5.0:0.001:5.0

# %%
plot(XX,f.(XX),":",label = "orig normal")
plot(XX,f_rm.(XX),":",label = "rm normal")
# Out:
# UndefVarError: f not defined
#
# Stacktrace:
#  [1] top-level scope at In[20]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
emp_pdf(X[1:900001]);
emp_pdf(X_rm[1:900001]);

legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000432C3108>

# %%
lags = 0:1000

A_rm = my_autocor(X_rm[:],lags)
A    = my_autocor(X[:],lags) 

semilogy(lags*h,[A A_rm])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000043125C88>
#  PyObject <matplotlib.lines.Line2D object at 0x000000004318F4C8>

# %%
z_spect = z_spect_scalar(X[:], n = 3, p=100, ty = "ave")
z_spect_rm = z_spect_scalar(X_rm[:], n = 3, p=100, ty = "ave")

Θ = 2*π*(1:1000:nfft)/nfft
Z = exp.(im*Θ)

a = 1 + h*A[1,1]
z_spect_ana_fun(z) = h*σ/( (1-a*z^(-1))*(1-a*z) )
z_spect_ana = real(z_spect_ana_fun.(Z))

semilogy(Θ,[z_spect[1:1000:nfft] z_spect_rm[1:1000:nfft] z_spect_ana])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 3-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000042C25F88>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000042BDED88>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000042BDE788>

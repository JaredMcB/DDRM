# %% [markdown]
# # Model Reduction on a Linear SDE

# %%
include("modgen_LSDE.jl")
include("..\\..\\Tools\\Model_Reduction_Dev.jl")
# Out:
# vector_wiener_filter_fft

# %%
using JLD
using PyPlot
using DSP: nextfastfft
using Distributions
# Out:
# ┌ Info: Precompiling Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
# └ @ Base loading.jl:1260

# %% [markdown]
# the model is
# $$dX_t = AX_tdt + \sigma dW_t$$
# my implementation of Euler-Maruyama produces
# $$ X_{n+1} = (1 + hA)X_n + \sqrt{h}\sigma u_n \qquad \text{where }u_n \sim N(0,1)$$

# %% [markdown]
# ## Generate the data

# %%
A = reshape([-0.5],1,1)
σ = reshape([1],1,1)
Xo = [1]
t_disc = 1000
gap = 1
scheme = "EM"

t_start = 0
t_stop  = 1e5
h       = 1e-2

Δt      = h*gap
M_out   = 20

X = modgen_LSDE(t_start,t_stop,h,
    A = A,
    σ = σ,
    Xo = Xo,
    t_disc = t_disc,
    gap = gap,
    scheme = scheme)

d, N = size(X)

nfft = nextfastfft(N)
X = [X zeros(d,nfft-N)]


τ_exp, τ_int    = auto_times(X[:])*Δt
N_eff           = N*Δt/τ_int

Psi(x) = x
# Out:
# Psi (generic function with 1 method)

# %%
@time h_wf = get_wf(X, Psi, par = 2000);
X = X[:,1:N]
# Out:
# Number of CKMS iterations: 575
# errK errR : 6.260470224456427e-11 1.0724368089566335e-15
#  74.908075 seconds (524.35 M allocations: 26.202 GiB, 15.04% gc time)
# 1×9900001 Array{Float64,2}:
#  0.207399  0.169424  0.130111  -0.0284967  …  0.445835  0.401593  0.241192

# %%
(τ_exp, N_eff)
# Out:
# (1.965017791564372, 49821.326681329956)

# %%
1 .+ h*A
# Out:
# 1×1 Array{Float64,2}:
#  0.995

# %%
h_wf
# Out:
# 1×1×20 Array{Float64,3}:
# [:, :, 1] =
#  0.9951234620825463
#
# [:, :, 2] =
#  -0.0007138256939601366
#
# [:, :, 3] =
#  0.00023503145096658595
#
# ...
#
# [:, :, 18] =
#  -0.0002145654178583164
#
# [:, :, 19] =
#  0.00046611708707075354
#
# [:, :, 20] =
#  -0.0010471943924805307

# %% [markdown]
# ## Get reduced (reproduced) model (no noise)

# %%
# d, N  = size(X)
# nu    = size(Psi(X[:,1]),1) 
# M_out = size(h_wf,3)

# X_rm = zeros(d,N); X_rm[:,1:M_out] = X[:,1:M_out]

# PSI = zeros(nu,N); 
# for i = 1:M_out
#     PSI[:,i] = Psi(X_rm[:,i])
# end

# for i = M_out + 1 : N
#     X_rm[:,i] = sum(h_wf[:,:,k]*PSI[:,i-k] for k = 1:M_out, dims = 2)
#     PSI[:,i] = Psi(X_rm[:,i])
# end

# %% [markdown]
# ## Get reduced (reproduced) model with noise

# %%
d, N  = size(X)
nu    = size(Psi(X[:,1]),1) 
M_out = 2 #size(h_wf,3)

X_rm = zeros(d,N); X_rm[:,1:M_out] = X[:,1:M_out]

PSI = zeros(nu,N); 
for i = 1:M_out
    PSI[:,i] = Psi(X_rm[:,i])
end

for i = M_out + 1 : N
    X_rm[:,i] = sum(h_wf[:,:,k]*PSI[:,i-k] for k = 1:M_out, dims = 2) + sqrt(h)*σ*randn(d)
    PSI[:,i] = Psi(X_rm[:,i])
end

# %%
X_rm
# Out:
# 1×9900001 Array{Float64,2}:
#  0.207399  0.169424  0.163487  0.288122  …  1.493  1.47454  1.29489  1.27616

# %%
data = Dict(
        "h_wf" => h_wf,
        "A" => A,
        "σ" => σ,
        "Xo" => Xo,
        "t_disc" => t_disc,
        "gap" => gap,
        "scheme" => scheme,
        "t_start" => t_start,
        "t_stop" => t_start,
        "h" => h,
        "X_55" => X,
        "X__rm_55_h_4" => X_rm)

save("LSDE_Data\\LSDE_wfs_M$M_out.jld",data)

# %%
pwd()
# Out:
# "C:\\Users\\JaredMcBride\\Desktop\\DDMR\\Examples\\LinearSDE"

# %%
data = load("LSDE_Data\\LSDE_wfs_M10.jld")
# Out:
# Dict{String,Any} with 19 entries:
#   "h_wf_55"               => [3.60053 3.94868; -0.722608 0.998188]…
#   "h_wf_4"                => [-45.398 7.5126; -0.351852 0.970747]…
#   "h_wf_5"                => [3.11491 4.01218; -0.708957 0.997011]…
#   "h"                     => 0.01
#   "_creator\\JULIA_PATCH" => 0x00000000
#   "t_disc"                => 1000
#   "X__rm_55_h_4"          => [-25.8263 -25.6386 … NaN NaN; -0.072074 -0.14603 ……
#   "t_start"               => 0
#   "σ"                     => [1 0; 0 1]
#   "t_stop"                => 0
#   "Xo"                    => [1, 1]
#   "scheme"                => "EM"
#   "A"                     => [-0.1 -10.0; -0.0 -0.9]
#   "_creator\\JULIA_MINOR" => 0x00000004
#   "_creator\\ENDIAN_BOM"  => 0x04030201
#   "gap"                   => 1
#   "_creator\\WORD_SIZE"   => 64
#   "X_55"                  => [-25.8263 -25.6386 … -7.85984 -7.85726; -0.072074 …
#   "_creator\\JULIA_MAJOR" => 0x00000001

# %%
blup = findall(isnan,X_rm[1,:])[1]
# Out:
# BoundsError: attempt to access 0-element Array{Int64,1} at index [1]
#
# Stacktrace:
#  [1] getindex(::Array{Int64,1}, ::Int64) at .\array.jl:744
#  [2] top-level scope at In[11]:1

# %%
findall(x -> x > 10^1,X_rm[1,:])[1]
# Out:
# BoundsError: attempt to access 0-element Array{Int64,1} at index [1]
#
# Stacktrace:
#  [1] getindex(::Array{Int64,1}, ::Int64) at .\array.jl:744
#  [2] top-level scope at In[12]:1

# %%
plot([X[1:1000:end] X_rm[1:1000:end]])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000040BF5C48>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000040C44808>

# %%
m = mean(X[1:9900001])
m_rm = mean(X_rm[1:9900001])
v = var(X[1:9900001])
v_rm = var(X_rm[1:9900001])

dist_rm = Normal(m_rm,v_rm)

f_rm(x) = pdf(dist_rm, x)

NN = 1000
XX = -5:1/NN:5
# Out:
# -5.0:0.001:5.0

# %%
plot(XX,f.(XX),":",label = "orig normal")
plot(XX,f_rm.(XX),":",label = "rm normal")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000040DB8E88>

# %%
emp_pdf(X[1:9900001]);
emp_pdf(X_rm[1:9900001]);

legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000040D88F88>

# %%
lags = 0:1000

A_rm = my_autocor(X_rm[:],lags)
A    = my_autocor(X[:],lags) 

semilogy(lags*h,[A A_rm])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\JaredMcBride\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000016E976C8>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000050D4B108>

# %%
z_spect = z_spect_scalar(X[:], n = 3, p=100, ty = "ave")
z_spect_rm = z_spect_scalar(X_rm[:], n = 3, p=100, ty = "ave")

Θ = 2*π*(1:1000:nfft)/nfft
Z = exp.(im*Θ)

a = 1 + h*A[1,1]
z_spect_ana_fun(z) = h*σ/( (1-a*z^(-1))*(1-a*z) )
z_spect_ana = real(z_spect_ana_fun.(Z))

semilogy(Θ,[z_spect[1:1000:nfft] z_spect_rm[1:1000:nfft] z_spect_ana])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 3-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000041219148>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000041241EC8>
#  PyObject <matplotlib.lines.Line2D object at 0x00000000412470C8>

# %% [markdown]
# # Model Reduction on a Linear SDE

# %%
include("modgen_LSDE.jl")
include("..\\..\\Tools\\Model_Reduction_Dev.jl")
# Out:
# vector_wiener_filter_fft

# %%
using JLD
using PyPlot
using DSP: nextfastfft
using Distributions

# %% [markdown]
# the model is
# $$dX_t = AX_tdt + \sigma dW_t$$
# my implementation of Euler-Maruyama produces
# $$ X_{n+1} = (1 + hA)X_n + \sqrt{h}\sigma u_n \qquad \text{where }u_n \sim N(0,1)$$

# %% [markdown]
# ## Generate the data

# %%
A = reshape([-0.5],1,1)
σ = reshape([1],1,1)
Xo = [1]
t_disc = 1000
gap = 1
scheme = "EM"

t_start = 0
t_stop  = 1e4
h       = 1e-2

Δt      = h*gap
M_out   = 20

n = 2
p = 150

X = modgen_LSDE(t_start,t_stop,h,
    A = A,
    σ = σ,
    Xo = Xo,
    t_disc = t_disc,
    gap = gap)

d, N = size(X)

nfft = nextfastfft(N)
X = [X zeros(d,nfft-N)]


τ_exp, τ_int    = auto_times(X[:])*Δt
N_eff           = N*Δt/τ_int

Psi(x) = x
# Out:
# Psi (generic function with 1 method)

# %%
n = 2
p = 150

@time h_wf = get_wf(X, Psi; par = 2000,n,p);
X = X[:,1:N]
# Out:
# Number of CKMS iterations: 1280
# errK errR : 9.0340390054216e-11 3.244357406286434e-14
#   3.006360 seconds (34.32 M allocations: 2.385 GiB, 14.35% gc time)
# 1×900001 Array{Float64,2}:
#  1.94753  1.96859  2.15003  2.07948  …  1.85428  1.92195  1.92354  1.97348

# %%
(τ_exp, N_eff)
# Out:
# (1.985312900169461, 4509.632473376151)

# %%
1 .+ h*A
# Out:
# 1×1 Array{Float64,2}:
#  0.995

# %%
h_wf
# Out:
# 1×1×20 Array{Float64,3}:
# [:, :, 1] =
#  0.99510660436287
#
# [:, :, 2] =
#  0.00035087789232835154
#
# [:, :, 3] =
#  -0.002344237451260443
#
# ...
#
# [:, :, 18] =
#  0.0002321026482148119
#
# [:, :, 19] =
#  -0.0011552980747423407
#
# [:, :, 20] =
#  0.00010824348022824984

# %% [markdown]
# ## Get reduced (reproduced) model (no noise)

# %%
# d, N  = size(X)
# nu    = size(Psi(X[:,1]),1) 
# M_out = size(h_wf,3)

# X_rm = zeros(d,N); X_rm[:,1:M_out] = X[:,1:M_out]

# PSI = zeros(nu,N); 
# for i = 1:M_out
#     PSI[:,i] = Psi(X_rm[:,i])
# end

# for i = M_out + 1 : N
#     X_rm[:,i] = sum(h_wf[:,:,k]*PSI[:,i-k] for k = 1:M_out, dims = 2)
#     PSI[:,i] = Psi(X_rm[:,i])
# end

# %% [markdown]
# ## Get reduced (reproduced) model with noise

# %%
d, N  = size(X)
nu    = size(Psi(X[:,1]),1) 
M_out = 2 #size(h_wf,3)

X_rm = zeros(d,N); X_rm[:,1:M_out] = X[:,1:M_out]

PSI = zeros(nu,N); 
for i = 1:M_out
    PSI[:,i] = Psi(X_rm[:,i])
end

for i = M_out + 1 : N
    X_rm[:,i] = sum(h_wf[:,:,k]*PSI[:,i-k] for k = 1:M_out, dims = 2) + sqrt(h)*σ*randn(d)
    PSI[:,i] = Psi(X_rm[:,i])
end

# %%
X_rm
# Out:
# 1×9900001 Array{Float64,2}:
#  -0.781925  -0.749833  -0.622137  -0.680348  …  -2.28985  -2.20863  -2.10841

# %%
data = Dict(
        "h_wf" => h_wf,
        "A" => A,
        "σ" => σ,
        "Xo" => Xo,
        "t_disc" => t_disc,
        "gap" => gap,
        "scheme" => scheme,
        "t_start" => t_start,
        "t_stop" => t_start,
        "h" => h,
        "X_55" => X,
        "X__rm_55_h_4" => X_rm)

save("LSDE_Data\\LSDE_wfs_M$M_out.jld",data)
# Out:
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 0:
#   #000: E:/mingwbuild/mingw-w64-hdf5/src/hdf5-1.10.5/src/H5F.c line 444 in H5Fcreate(): unable to create file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: E:/mingwbuild/mingw-w64-hdf5/src/hdf5-1.10.5/src/H5Fint.c line 1509 in H5F_open(): unable to open file: time = Fri Oct 02 10:56:30 2020
# , name = 'LSDE_Data\LSDE_wfs_M2.jld', tent_flags = 13
#     major: File accessibilty
#     minor: Unable to open file
#   #002: E:/mingwbuild/mingw-w64-hdf5/src/hdf5-1.10.5/src/H5FD.c line 734 in H5FD_open(): open failed
#     major: Virtual File Layer
#     minor: Unable to initialize object
#   #003: E:/mingwbuild/mingw-w64-hdf5/src/hdf5-1.10.5/src/H5FDsec2.c line 346 in H5FD_sec2_open(): unable to open file: name = 'LSDE_Data\LSDE_wfs_M2.jld', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 302
#     major: File accessibilty
#     minor: Unable to open file
# Error creating file LSDE_Data\LSDE_wfs_M2.jld
#
# Stacktrace:
#  [1] error(::String, ::String) at .\error.jl:42
#  [2] h5f_create at C:\Users\jared\.julia\packages\HDF5\T1b9x\src\HDF5.jl:2334 [inlined]
#  [3] jldopen(::String, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool; mmaparrays::Bool, compatible::Bool, compress::Bool) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:167
#  [4] jldopen(::String, ::String; mmaparrays::Bool, compatible::Bool, compress::Bool) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:231
#  [5] jldopen(::JLD.var"#36#37"{Dict{String,Any}}, ::String, ::Vararg{String,N} where N; kws::Base.Iterators.Pairs{Symbol,Bool,Tuple{Symbol,Symbol},NamedTuple{(:compatible, :compress),Tuple{Bool,Bool}}}) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:241
#  [6] save(::FileIO.File{FileIO.DataFormat{:JLD}}, ::Dict{String,Any}; compatible::Bool, compress::Bool) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:1218
#  [7] save at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:1218 [inlined]
#  [8] save(::String, ::Dict{String,Any}; options::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at C:\Users\jared\.julia\packages\FileIO\wN5rD\src\loadsave.jl:136
#  [9] save(::String, ::Dict{String,Any}) at C:\Users\jared\.julia\packages\FileIO\wN5rD\src\loadsave.jl:136
#  [10] top-level scope at In[31]:15
#  [11] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [12] execute_code(::String, ::String) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [13] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [14] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [15] invokelatest at .\essentials.jl:709 [inlined]
#  [16] eventloop(::ZMQ.Socket) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [17] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
data = load("LSDE_Data\\LSDE_wfs_M10.jld")
# Out:
# File LSDE_Data\LSDE_wfs_M10.jld cannot be found
#
# Stacktrace:
#  [1] error(::String, ::String, ::String) at .\error.jl:42
#  [2] jldopen(::String, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool; mmaparrays::Bool, compatible::Bool, compress::Bool) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:153
#  [3] jldopen(::String, ::String; mmaparrays::Bool, compatible::Bool, compress::Bool) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:231
#  [4] jldopen(::String, ::String) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:231
#  [5] jldopen(::JLD.var"#42#44", ::String, ::Vararg{String,N} where N; kws::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:241
#  [6] jldopen(::Function, ::String, ::String) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:241
#  [7] load(::FileIO.File{FileIO.DataFormat{:JLD}}) at C:\Users\jared\.julia\packages\JLD\jeGJb\src\JLD.jl:1245
#  [8] load(::String; options::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at C:\Users\jared\.julia\packages\FileIO\wN5rD\src\loadsave.jl:133
#  [9] load(::String) at C:\Users\jared\.julia\packages\FileIO\wN5rD\src\loadsave.jl:133
#  [10] top-level scope at In[33]:1
#  [11] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [12] execute_code(::String, ::String) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [13] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [14] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [15] invokelatest at .\essentials.jl:709 [inlined]
#  [16] eventloop(::ZMQ.Socket) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [17] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
blup = findall(isnan,X_rm[1,:])[1]
# Out:
# BoundsError: attempt to access 0-element Array{Int64,1} at index [1]
#
# Stacktrace:
#  [1] getindex(::Array{Int64,1}, ::Int64) at .\array.jl:809
#  [2] top-level scope at In[34]:1
#  [3] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [4] execute_code(::String, ::String) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [6] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [7] invokelatest at .\essentials.jl:709 [inlined]
#  [8] eventloop(::ZMQ.Socket) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [9] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
findall(x -> x > 10^1,X_rm[1,:])[1]
# Out:
# BoundsError: attempt to access 0-element Array{Int64,1} at index [1]
#
# Stacktrace:
#  [1] getindex(::Array{Int64,1}, ::Int64) at .\array.jl:809
#  [2] top-level scope at In[35]:1
#  [3] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [4] execute_code(::String, ::String) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [6] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [7] invokelatest at .\essentials.jl:709 [inlined]
#  [8] eventloop(::ZMQ.Socket) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [9] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
plot([X[1:1000:end] X_rm[1:1000:end]])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000048877288>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000044AA85C8>

# %%
m = mean(X[1:9900001])
m_rm = mean(X_rm[1:9900001])
v = var(X[1:9900001])
v_rm = var(X_rm[1:9900001])

dist_rm = Normal(m_rm,v_rm)

f_rm(x) = pdf(dist_rm, x)

NN = 1000
XX = -5:1/NN:5
# Out:
# -5.0:0.001:5.0

# %%
plot(XX,f.(XX),":",label = "orig normal")
plot(XX,f_rm.(XX),":",label = "rm normal")
# Out:
# UndefVarError: f not defined
#
# Stacktrace:
#  [1] top-level scope at In[38]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [3] execute_code(::String, ::String) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [5] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [6] invokelatest at .\essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
emp_pdf(X[1:9900001]);
emp_pdf(X_rm[1:9900001]);

legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000047F905C8>

# %%
lags = 0:1000

A_rm = my_autocor(X_rm[:],lags)
A    = my_autocor(X[:],lags) 

semilogy(lags*h,[A A_rm])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000452DB448>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000044AF2148>

# %%
z_spect = z_spect_scalar(X[:], n = 3, p=100, ty = "ave")
z_spect_rm = z_spect_scalar(X_rm[:], n = 3, p=100, ty = "ave")

Θ = 2*π*(1:1000:nfft)/nfft
Z = exp.(im*Θ)

a = 1 + h*A[1,1]
z_spect_ana_fun(z) = h*σ/( (1-a*z^(-1))*(1-a*z) )
z_spect_ana = real(z_spect_ana_fun.(Z))

semilogy(Θ,[z_spect[1:1000:nfft] z_spect_rm[1:1000:nfft] z_spect_ana])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 3-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000045AD7EC8>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000045AFBB48>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000045AFBD08>

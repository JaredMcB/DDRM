# %%
using PyPlot
using JLD
using Dates
using DSP: conv

mr = include("../../Tools/Model_Reduction_Dev.jl")
at = include("../../Tools/AnalysisToolbox.jl")

server = startswith(pwd(), "/u5/jaredm") ? true : false
# When I want the standard lin et al. (2017) data.
sol_file = server ? "../../../data/KSE_Data/KSE_sol_lin.jld" :
   "Examples/KSE/Data/KSE_sol_lin.jld"
# Out:
# WARNING: replacing module Model_Reduction_Dev.
# WARNING: replacing module AnalysisToolbox.
# "../../../data/KSE_Data/KSE_sol_lin.jld"

# %%
# Load Old Data
@time Data = load(sol_file)
print("Data Loaded")
uu      = Data["dat_uu"];
vv      = Data["dat_vv"];
tt      = Data["dat_tt"];
obs_gap = Data["obs_gap"];
h       = Data["h"];

# %%
P      = Data["P"]
N      = Data["N"]

Δt = h*gap
# Out:
# 0.1

# %%
t_start = 0
t_stop = 150
ind_start = floor(Int,t_start/Δt)+1
ind_stop =floor(Int,t_stop/Δt)

H1 = imshow(uu[:,ind_start:ind_stop]', extent=[0,21.55,0,150], aspect="auto")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x7ff743a7dee0>

# %%
## Build Psi
function InvBurgRK4_1step(x)
   lx = length(x)
   function F(x)
      𝑥 = [conj(reverse(x, dims = 1)); 0; x]
      -im / 2 * (2π / P * (1:lx) / N) .* conv(𝑥, 𝑥)[2*lx+2:3*lx+1]
   end

   Δt = h * obs_gap

   k1 = F(x)
   k2 = F(x .+ Δt * k1 / 2)
   k3 = F(x .+ Δt * k2 / 2)
   k4 = F(x .+ Δt * k3)
   A = @. x + Δt / 6 * (k1 + 2k2 + 2k3 + k4)
end

function Inertialman_part_short(x)
   lx = length(x)
   𝑥(j) = (j <= lx ? x[j] : im * sum(x[l] * x[j-l] for l = j-lx:lx))

   L = complex(zeros(binomial(lx + 1, 2)))
   i = 1
   for j = 1:lx
      for k = j:lx # k should normaly go from 1 to lx but i changed it to go from j to lx.
         L[i] = 𝑥(j + lx) * 𝑥(j + lx - k)
         i += 1
      end
   end
   L
end

Psi(x) = [x; InvBurgRK4_1step(x); Inertialman_part_short(x)]
# Out:
# Psi (generic function with 1 method)

# %%
sig = vv[2:6,2:end]
# Out:
# 5×500000 Array{Complex{Float64},2}:
#  -75.0373+105.738im  -76.3976+104.75im   …  -9.94987-43.2958im
#  -414.239+79.4992im  -418.783+74.4633im       -221.8+49.0733im
#    166.09+203.738im   167.297+196.795im     -57.7592+95.383im
#  -28.9891+4.78464im   -19.914-1.62628im     -7.17876+57.3711im
#  -31.5592+65.201im   -27.1491+67.5943im       17.782+60.4354im

# %%
pred = mr.get_pred(vv[2:6,1:end-1], Psi)
# Out:
# 25×500000 Array{Complex{Float64},2}:
#    -73.4911+106.602im      -75.0373+105.738im    …    -8.56738-41.4098im
#      -409.3+84.7447im      -414.239+79.4992im         -224.247+44.949im
#      164.86+210.838im        166.09+203.738im         -54.2359+103.867im
#    -38.0952+11.1861im      -28.9891+4.78464im         -4.85775+53.5824im
#    -35.8533+62.8729im      -31.5592+65.201im            15.438+61.6427im
#     -88.328+109.159im      -89.7963+109.331im    …    -18.6775-48.9826im
#    -403.954+62.0741im      -408.108+59.5112im          -232.67+41.8987im
#     90.4457+145.04im        89.3492+140.378im         -57.2907+97.5206im
#    -75.1652-75.081im       -65.5745-84.4612im         -16.6891+19.1894im
#    -139.839+151.69im       -131.103+152.995im         -23.5946+46.0724im
#   1.08328e6-2.46659e6im   1.32756e6-2.78936e6im  …    935653.0+2.25957e6im
#   1.36683e6-561909.0im     1.2349e6-212174.0im        117509.0+2.06727e6im
#  -6.92099e6-7.16525e6im  -7.14007e6-8.64184e6im     -1.47846e6+4.2603e6im
#   1.48229e7-4.72528e6im    1.7643e7-3.50646e6im     -8.28325e6+2.97693e6im
#   2.30691e6-4.23142e6im   3.17032e6-4.53027e6im      -559890.0-1.52809e6im
#  -2.59586e6+4.34533e6im  -2.45959e6+4.38317e6im  …   1.93274e6+1.68299e6im
#  -2.67946e6+728206.0im   -2.02784e6+209621.0im       1.07542e6+1.88456e6im
#   1.12286e7+1.49752e7im   1.06474e7+1.48081e7im       602034.0+4.68709e6im
#  -2.87382e7+5.34598e6im  -2.90234e7+3.76617e6im      -6.3811e6+6.66013e6im
#   2.49742e6+1.02758e6im    2.6314e6+587901.0im       1.12986e6-20923.4im
#    595291.0+1.35656e6im    420393.0+1.00961e6im  …    909009.0+298505.0im
#   7.01787e6-7.10459e6im   5.96685e6-7.75416e6im      1.58279e6+1.35524e6im
#   -283818.0+304104.0im    -207453.0+228111.0im        400158.0-169362.0im
#   -227867.0+12078.2im     -124110.0-15423.6im         367125.0-23738.5im
#     6075.44+379096.0im      82363.5+371059.0im        190157.0-172305.0im

# %%
lags = -4000:4000
let plt = plot
    for m = 1:25
        figure()
        A = at.my_crosscov(pred[m,:],pred[m,:],lags)
        plt(Δt*lags,A)
        legend()
        title("modes $m and $m")
    end
end

# %%
n = 5
lags = -10000:10000
let plt = plot
    for m = 1:25
        figure()
        A = at.my_crosscov(sig[n,:],pred[m,:],lags)
        plt(Δt*lags,A)
        legend()
        title("modes $n and $m")
    end
end

# %%
L = 1000
Nex = 2^12
# Out:
# 4096

# %%
z_crossspect_sigpred_num_fft = at.z_crossspect_fft_old(sig, pred; L, Nex);

# %%
L = 1000
Nex = 2^14

Theta = 2π/Nex*(0:Nex-1)
points = 

n = 1
m = 2
S_sigpred2 = at.z_crossspect_dm(sig[n,:],pred[m,:]; L, Nex)
semilogx(Theta[1:end÷points:end],S_sigpred[1:end÷points:end])
semilogx(Theta[1:end÷points:end],S_sigpred2[1:end÷points:end])
# Out:
# ArgumentError: step cannot be zero
#
# Stacktrace:
#  [1] steprange_last(::Int64, ::Int64, ::Int64) at ./range.jl:215
#  [2] StepRange at ./range.jl:205 [inlined]
#  [3] StepRange at ./range.jl:256 [inlined]
#  [4] _colon at ./range.jl:24 [inlined]
#  [5] (::Colon)(::Int64, ::Int64, ::Int64) at ./range.jl:22
#  [6] top-level scope at In[67]:10
#  [7] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
n = 1
m = 6
semilogx(Theta[1:end ÷ points:end],z_crossspect_sigpred_num_fft[n,m,1:end÷points:end])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7ff725741a30>

# %%
S_sigpred = z_crossspect_dm(sig[n,:],pred; L, Nex)
semilogy(Theta[1:end ÷ points:end],z_crossspect_sigpred_num_fft[n,m,1:end÷points:end])

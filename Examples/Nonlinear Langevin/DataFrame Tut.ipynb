# %%
using StatsPlots
using DataFrames
# Out:
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1260

# %%
T = reshape(1:100,5,20)
# Out:
# 5×20 reshape(::UnitRange{Int64}, 5, 20) with eltype Int64:
#  1   6  11  16  21  26  31  36  41  …  56  61  66  71  76  81  86  91   96
#  2   7  12  17  22  27  32  37  42     57  62  67  72  77  82  87  92   97
#  3   8  13  18  23  28  33  38  43     58  63  68  73  78  83  88  93   98
#  4   9  14  19  24  29  34  39  44     59  64  69  74  79  84  89  94   99
#  5  10  15  20  25  30  35  40  45     60  65  70  75  80  85  90  95  100

# %%
df = DataFrame(T)
# Out:
# 5×20 DataFrame. Omitted printing of 11 columns
# │ Row │ x1    │ x2    │ x3    │ x4    │ x5    │ x6    │ x7    │ x8    │ x9    │
# │     │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │
# ├─────┼───────┼───────┼───────┼───────┼───────┼───────┼───────┼───────┼───────┤
# │ 1   │ 1     │ 6     │ 11    │ 16    │ 21    │ 26    │ 31    │ 36    │ 41    │
# │ 2   │ 2     │ 7     │ 12    │ 17    │ 22    │ 27    │ 32    │ 37    │ 42    │
# │ 3   │ 3     │ 8     │ 13    │ 18    │ 23    │ 28    │ 33    │ 38    │ 43    │
# │ 4   │ 4     │ 9     │ 14    │ 19    │ 24    │ 29    │ 34    │ 39    │ 44    │
# │ 5   │ 5     │ 10    │ 15    │ 20    │ 25    │ 30    │ 35    │ 40    │ 45    │

# %%
@df df boxplot(T,marker=(0.3,:orange,stroke(2)), alpha=0.75, leg = :none)

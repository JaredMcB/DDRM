# %% [markdown]
# # Langevin Equation Test Case (p1q1)

# %% [markdown]
# ## Producing the data

# %% [markdown]
# For this notebook we consider the stochastic overdamped Langevin equation with a double-welled potential $V(x) = \frac{1}{4}(x^2 - 1)^2$. So, we consider the following SDE.
# $$dX_t = -X_t(X_t^2 - 1)dt + dB_t$$
# To find a numerical solution we first use the Euler-Maruyama scheme
# $$X_{n+1} = X_n - h X_n(X_n^2 - 1) + \nu_n$$
# here $$\nu_n \sim (B_{t_{n+1}}-B_{t_{n}}) \sim N(0,h) \sim \sqrt{h} N(0,1).$$
#
# Now we generate the sample path.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as sa
import scipy.optimize as so

# %%
start = 0
stop = 10**4
steps = stop*100 + 1

dVdx = lambda x : -x*(x**2 -1) 

x_init = .5

# %%
h = (stop - start)/(steps - 1)
t = np.linspace(start,stop,steps)

X = np.zeros(steps)
X[0] = x_init

for n in range(steps - 1):
    X[n+1] = X[n] + h*dVdx(X[n]) + np.sqrt(h)*np.random.normal(0,1)

# %%
plt.plot(t[:1000],X[:1000])

# %%
def sim(X,Psi,A_init):
    N = len(X)

    A_sol = A_init
        
    # Then we run it
    a = A_sol[0]
    b = np.reshape(A_sol[1:],[2,2])

    Y = np.zeros(N)
    y = np.zeros(N-1)
    Y[:1] = X[:1]
    y[0] = X[1]
    for i in range(1,N-1):
        y[i] = -a*y[i-1] + b[1] @ Psi(Y[i]) + b[0] @ Psi(Y[i-1])
        Y[i+1] = y[i] + np.sqrt(abs(b[1][0]))*np.random.normal(0,1)
        
    return Y

# %% [markdown]
# The graph below display two realizations of the same stochastic process.

# %%
Psi = lambda x : np.array([dVdx(x), x])
A_init = [0,0,0,h,1]
Y = sim(X,Psi,A_init)
plt.plot(t[:1000],X[:1000])
plt.plot(t[:1000],Y[:1000])

# %%
np.mean(X),np.mean(Y)
# Out:
# (0.02636527846135569, 0.020151677816505235)

# %%
np.var(X),np.var(Y)
# Out:
# (0.8922808647952293, 0.8950617614597636)

# %% [markdown]
# ## Proposing the test

# %% [markdown]
# We seek to fit something of the form $p = 1$, $q=1$
#
# \begin{align}
# Y_{n+1} &= y_n +\xi_{n+1} \\
# y_{n} &= -ay_{n-1} + b_0 \Psi(Y_{n-1}) + b_1\Psi(Y_n)\\
# \end{align}
# where $\Psi(x) =-\frac{dV}{dx} = -x(x^2 - 1)$, $Y_{0:1} = X_{0:1}$, and $y_0 = X_1$. This coresponds to a NARMAX model.

# %% [markdown]
# To fit we use for our loss function the mean squared one-step error:
# $$\frac{1}{N}\sum_{n=1}^{N} \|X_{n} - y_{n-1}\|^2.$$
# So that the mimimization problem may be rendered as follows:
# \begin{align}
# \min_{a,b} &\frac{1}{N}\sum_{n=1}^{N} \|X_{n} - y_{n-1}\|^2 \\
# \text{s.t. } & y_0 = X_1 \\
# & y_n = -a y_{n-1} + b_1\Psi(X_n) + b_0\Psi(X_{n-1}) \qquad \text{for } n = 1,\dots, N-1 \\
# \end{align}

# %% [markdown]
# It clear that if $\Psi(x) = \big(-x(x^2-1),x\big)^T$ and $a=0$,
# $b = \begin{pmatrix} 0 & h \\ 0 & 1 \end{pmatrix}$  can be shown that the NARMAX model above for $Y_n$ and the Euler-Maruyama scheme for $X_n$ are different formulations of the same discrete time stochastic process.
# And so, we expect there to be a local minimum to the optimization problem at $A = (a,\vec{b}) = (0,0,0,h,1)$ where $\vec{b} = (b_1^T,b_2^T)$ and $b_i$ is the $i$th column of $b$

# %% [markdown]
# The optimization problem above is coded as follows.

# %%
def modReduction(X,Psi,A_init):
    N = len(X)
    
    def aux_fun(A, X, Psi, N):
        a = A[0]
        b = np.reshape(A[1:],[2,2])
        
        y = np.zeros(N-1)
        y[0] = X[1]
        for i in range(1,N-1):
            y[i] = -a*y[i-1] + b[1] @ Psi(X[i]) + b[0] @ Psi(X[i-1])
        return X[1:] - y

    obj_fun = lambda A : aux_fun(A, X, Psi, N)
    
    A_sol = so.least_squares(obj_fun,A_init).x
        
    # Then we run it
    a = A_sol[0]
    b = np.reshape(A_sol[1:],[2,2])

    Y = np.zeros(N)
    y = np.zeros(N-1)
    
    Y[:1] = X[:1]
    y[0] = X[1]
    for i in range(1,N-1):
        y[i] = -a*y[i-1] + b[1] @ Psi(Y[i]) + b[0] @ Psi(Y[i-1])
        Y[i+1] = y[i] + np.sqrt(abs(b[1][0]))*np.random.normal(0,1)
        
    return [Y,A_sol]

# %% [markdown]
# Now to implement this. First, we set $\Psi$ and an initial guess at the parameters $a$ and $b$, we let $A = (a,\vec{b})$.

# %% [markdown]
# ## Preparing for fitting

# %% [markdown]
# The above fit will work if the data is stationary. To ensure stationarity we estimate the exponential autocorrelation time $\tau_{exp}$. To do that, we estimate the autocorrelation function. Here this is done by using the `acorr` function in `matplotlib`. It is ploted and we observe the exponential decay of the transient behavior to the mean zero, noise drive behavior.

# %%
maxlags = 4000
[lags,c] = plt.acorr(X,maxlags = maxlags)[:2]

# %% [markdown]
# We truncate the autocorrelation function to isolate the exponetial.

# %%
trunc = 900
lags_tr = lags[maxlags:maxlags + trunc]
c_tr = c[maxlags:maxlags + trunc]

# %% [markdown]
# Then we fit a line to the log of the exponetial to recover the exponential autocorrelation time.

# %%
x = np.array(range(trunc))*h
y = np.log(c_tr)

# %%
plt.plot(x,y)

A = np.matrix([[xx] for xx in x])
B = sa.pinv(A) @ np.matrix(y).T.A1
Y = [B*xx for xx in x]

plt.plot(x,Y)

tau = -1/B[0]
tau
# Out:
# 2.028366252724845

# %% [markdown]
# Here we can check the fit.

# %%
y = np.exp(-np.abs(lags)*h/tau)
plt.plot(lags,c)
plt.plot(lags,y)

# %% [markdown]
# So, we find that the exponential autocorreltation time is around

# %%
n_disc = int(tau*20) +1
tau, n_disc
# Out:
# (2.028366252724845, 41)

# %% [markdown]
# Suggesting that discarding $20\tau \approx 39$ samples will safely exclude the transient behave resulting from starting with a point distribution.

# %% [markdown]
# Now, to determine how long we should run the initial system we seek the integrated autocorrelation time $\tau_{int}$, defined as $$\tau_{int} = \sum_{k = -\infty}^{\infty} \overline{C}{k}.$$

# %%
[lags,c] = plt.acorr(X,maxlags = None)[:2]

# %%
maxlags = int((len(c) - 1) / 2)
C = 10
m = lags[maxlags:]
Y1 = np.cumsum(c[maxlags:])
Y2 = m/C
M = np.nonzero((Y2 - Y1) > 0)[0][0]
plt.plot(m,Y1,m,Y2)
plt.axis([0, 1.1*M, 0, 1.1*M/C])
# Out:
# [0, 2366.1000000000004, 0, 236.61000000000004]

# %%
tau_int = np.sum(c[maxlags - M : maxlags + M ])
(steps - n_disc)/tau_int
# Out:
# 2330.011568087569

# %% [markdown]
# Which means we should have effectively about $N/\tau_{int} \approx 2136$ independent samples.

# %% [markdown]
# ## Fitting

# %% [markdown]
# To fit we use the information above which suggests we discard the first 40 seconds of samples.

# %%
Z = X[n_disc:]

# %%
A_init = [0,0,0,0,0]
[Y,A_sol] = modReduction(Z,Psi,A_init)
A_sol
# Out:
# C:\Users\JaredMcBride\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# array([-0.26732927, -0.00267357, -0.26693161,  0.0100209 ,  0.99963437])

# %%
plt.plot(t[:1000],Z[:1000])
plt.plot(t[:1000],Y[:1000])

# %%
np.mean(Y),np.mean(Z)
# Out:
# (0.020151677816505235, 0.02634682443679509)

# %%
np.var(Y),np.var(Z)
# Out:
# (0.8950617614597636, 0.8923084620662182)

# %%
maxlags = 4000
[lags,c] = plt.acorr(Z,maxlags = maxlags)[:2]

# %%
maxlags = 4000
[lags,c] = plt.acorr(Y,maxlags = maxlags)[:2]

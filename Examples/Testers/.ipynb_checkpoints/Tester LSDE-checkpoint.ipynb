# %% [markdown]
# # Tester: Linear SDE's

# %% [markdown]
# A Linear SDE for a $n$-dimensional system is of the form
#     $$ dX_t = AX_tdt + \sigma dW_t $$
# where $W_t$ is a $m$-dimensional Wiener process.

# %%
using PyPlot

# Get software to generate model
include("../LinearSDE/modgen_LSDE.jl")

# Get model reduction software being tested
include("../../Tools/Model_Reduction_Dev.jl")

# Get tester tools
include("testertools.jl")
# Out:
# one_step_pred (generic function with 1 method)

# %%
# Model run Parameters
t_start = 0
t_stop  = 1e3
h       = 1e-2

A       = reshape([-0.5],1,1)
σ       = reshape([1],1,1)
Xo      = [1]
t_disc  = 100
gap     = 1

# Get full model run
X = modgen_LSDE(t_start,t_stop,h;
    A, σ, Xo, t_disc, gap)
# Out:
# 1×90001 Array{Float64,2}:
#  0.0637273  0.0448668  0.00842183  0.245315  …  -1.36627  -1.41024  -1.54868

# %%
# Put in Psi functions
Psi(x) = x
# Out:
# Psi (generic function with 1 method)

# %%
# Model reduction Parameters
M_out = 100
n = 2
p = 500
par = 1500
ty = "bin"
rl = true
Preds = true
PI = false
rtol = 1e-6

@time h_wf, pred = get_wf(X, Psi;
    M_out, n, p, par, ty, rl, Preds, PI, rtol);

X_sig = X[:,2:end]
# Out:
# Number of CKMS iterations: 1073
# errK errR : 7.200139510045701e-11 1.6769182392185488e-15
#   0.511121 seconds (3.58 M allocations: 483.752 MiB, 13.23% gc time)
# 1×90000 Array{Float64,2}:
#  0.0448668  0.00842183  0.245315  0.358512  …  -1.36627  -1.41024  -1.54868

# %% [markdown]
# ## Analyze Wiener Filter

# %%
h_wf
# Out:
# 1×1×100 Array{Float64,3}:
# [:, :, 1] =
#  0.9577839702312572
#
# [:, :, 2] =
#  0.041934332396901905
#
# [:, :, 3] =
#  0.037220831978107834
#
# ...
#
# [:, :, 98] =
#  -0.015379976881844316
#
# [:, :, 99] =
#  -0.016125743261254637
#
# [:, :, 100] =
#  -0.01446734631398836

# %%
plot_WF(h_wf, rl = false)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Elements of h_wf over lags')

# %% [markdown]
# ## Analyze One step prediction error

# %%
X_hat = one_step_pred(X_sig, h_wf, pred)
# Out:
# 1×90000 Array{Complex{Float64},2}:
#  0.0448668+0.0im  0.00842183+0.0im  …  -1.73488+0.0im  -1.73615+0.0im

# %%
wind = (1:2000) .+ 24000
plot([X_sig[1,wind] X_hat[1,wind]])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000061809288>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000061810DC8>

# %%
X_err = X_sig - X_hat
# Out:
# 1×90000 Array{Complex{Float64},2}:
#  0.0-0.0im  0.0-0.0im  0.0-0.0im  …  0.324641-0.0im  0.187467-0.0im

# %%
C = my_crosscov(X_err[:],pred[:],-100:10)
# Out:
# 111-element Array{Complex{Float64},1}:
#  -0.10594001676185215 - 4.621063854443726e-18im
#  -0.10643740740424877 - 7.49213985340885e-18im
#  -0.10695093959476065 - 1.650658839963965e-17im
#  -0.10744933061599612 - 1.5420173114167845e-17im
#  -0.10796878039557274 - 9.826320721611401e-18im
#  -0.10845132432624412 - 1.0767037949084914e-17im
#  -0.10890406690242742 + 6.0925480101035396e-18im
#   -0.1093785510328038 + 1.464182587494138e-18im
#  -0.10979590983975052 + 5.732394399618963e-18im
#  -0.11024432059315512 + 1.0389827725135984e-17im
#  -0.11070495838033201 + 6.958218077453924e-18im
#  -0.11118574356964714 + 5.9166292394668886e-18im
#  -0.11165093313837068 - 2.170747260890662e-18im
#                       ⋮
#  -0.15741915395577474 + 2.9831149488986667e-18im
#   -0.1679489668638578 + 7.93714291011969e-18im
#  -0.16885946007486263 + 2.314029887776482e-18im
#  -0.16934122322087586 - 1.2321087654032774e-17im
#  -0.16939655210747495 - 2.356284187160686e-18im
#  -0.16903392542087173 - 1.7913239313340432e-18im
#  -0.16825515692065038 - 2.4603916197469583e-18im
#  -0.16708062186005287 - 1.6957909512626713e-17im
#   -0.1655149614722411 - 2.7318118898439817e-17im
#   -0.1635679426098649 - 1.346841918745333e-17im
#  -0.16125025309414964 - 2.8682953860223453e-18im
#  -0.15856681056615843 - 1.0672030082504934e-17im

# %%
plot(C)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000006187BA08>

# %% [markdown]
# ## Analyze Reduced Model Run

# %%
X_rm = redmodrun(X, h_wf, Psi)
# Out:
# reduced model blewup at step 1241

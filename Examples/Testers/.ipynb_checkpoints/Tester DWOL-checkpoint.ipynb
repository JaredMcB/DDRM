# %% [markdown]
# # Tester: Nonlinear Langevin
# ## Double-welled overdamped Langevin (DWOL)

# %% [markdown]
# ### Simple double well $V(x) = 1/4(x^2-1)^2$

# %% [markdown]
# Here we take for out potential the function $$V(x) = 1/4(x^2-1)^2$$ and so the (overdamped, stochastic) Langenvin equation is $$dX_t = -V'(X_t)dt + \sigma dW_t = -X_t(X_t^2-1) + \sigma dW_t$$
# We solve this numerically in various ways to get an approximate solution if to the equation. For instance we will often use Euler-Maruyama which soluction takes the form
# $$Y_{n+1} = Y_{n} + \Delta t\big(-Y_n(Y_n^2-1)\big) + \sigma \sqrt{\Delta t}v_n$$
# where $Y_n \approx X_{\Delta t n}$ and $v_n \sim N(0,1)$ for all $n = 0,1,2,\dots$ are i.i.d.
#
# The goal here is to reproduce the statisical and dynamical information (?). Of a realization of $Y = (Y_n;\;n=o,1,2,\dots)$ using a reduced model. We will compare the autocavariances as well as the pdf the $Y_n$.
#
# So, first we run the full model. To do this I use the function `DataGen_DWOL` found in th file `DataGen.jl` found in the current folder (`Examples\Nonlinear Langevin`).

# %%
using PyPlot
using Random
using JLD

# Get software to generate model
include("../Nonlinear Langevin/DataGen.jl")

# Get model reduction software being tested
include("../../Tools/Model_Reduction_Dev.jl")

# Get tester tools
include("testertools.jl")
# Out:
# causal_test (generic function with 1 method)

# %%
# Model run Parameters
steps = 10^7 + 1
scheme = "FE"
t_start = 0
t_stop = 10^5
discard = 100000
sig_init = [1.5]
sigma = [.5]
V_prime = x -> -x.*(x.^2 .- 1)
SM1 = false
Obs_noise = false
d = 1
# e = randn(d,steps + discard)

dt = (t_stop - t_start)/(steps - 1)

# Get full model run
Random.seed!(2014)
X = DataGen_DWOL(
    steps;
    scheme, t_start, t_stop, discard, 
    sig_init , sigma, V_prime,
    SM1, Obs_noise, d
    )
# Out:
# 1×10000001 Array{Float64,2}:
#  1.21912  1.2862  1.30297  1.2873  …  1.17377  1.23803  1.20563  1.23796

# %%
data = Dict("steps" => steps,
            "t_start" => t_start,
            "sigma" => sigma,
            "X" => X)
save("data_10_23_2020.jld",data)

# %%
data = load("data_10_23_2020.jld")
X = data["X"]
# Out:
# 1×10000001 Array{Float64,2}:
#  1.21912  1.2862  1.30297  1.2873  …  1.17377  1.23803  1.20563  1.23796

# %%
X = data["X"]
# Out:
# 1×10000001 Array{Float64,2}:
#  1.21912  1.2862  1.30297  1.2873  …  1.17377  1.23803  1.20563  1.23796

# %%
# Put in Psi functions
Psi(x) = [x; x.^3]

# Model reduction Parameters
M_out = 100
n = 3
p = 500
par = 55
ty = "bin"
xspec_est = "DM"
rl = false
Preds = true
PI = false
rtol = 1e-6

nfft = 2^16

@time h_pack_dm = get_wf(X, Psi;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol);

h_wf_dm                              = h_pack_dm[1][1]
# Out:
# Number of CKMS iterations: 229
# errK errR : 5.839641943327172e-11 1.7393616235168657e-14
#  37.282013 seconds (69.88 M allocations: 16.103 GiB, 4.80% gc time)
# 1×2×100 Array{Complex{Float64},3}:
# [:, :, 1] =
#  1.00976-2.37045e-14im  -0.00979518+6.17976e-15im
#
# [:, :, 2] =
#  -0.000758073-6.48571e-14im  0.000299071+1.79632e-14im
#
# [:, :, 3] =
#  0.00112176+1.79866e-13im  -0.000601638-4.81259e-14im
#
# ...
#
# [:, :, 98] =
#  1.67209e-6+5.18674e-15im  -4.14287e-7-1.36712e-15im
#
# [:, :, 99] =
#  7.50158e-7+3.78704e-15im  -1.87947e-7-1.02287e-15im
#
# [:, :, 100] =
#  -6.57134e-7-2.11936e-15im  1.58132e-7+5.93994e-16im

# %%
# Put in Psi functions
Psi(x) = [x; x.^3]

# Model reduction Parameters
M_out = 100
n = 3
p = 500
par = 10000
ty = "bin"
xspec_est = "DM"
rl = false
Preds = true
PI = false
rtol = 1e-6

nfft = 2^16

@time h_pack_dm = get_wf(X, Psi;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol);

h_wf_dm                              = h_pack_dm[1][1]
# Out:
# Number of CKMS iterations: 6801
# errK errR : 7.188946213993904e-11 4.083057817338725e-14
#  55.679377 seconds (34.48 M allocations: 57.836 GiB, 7.31% gc time)
# 1×2×100 Array{Complex{Float64},3}:
# [:, :, 1] =
#  1.00971-5.32819e-14im  -0.00979209+1.37593e-14im
#
# [:, :, 2] =
#  -0.000778425-3.73527e-14im  0.000310248+9.93868e-15im
#
# [:, :, 3] =
#  0.00129579+1.86277e-13im  -0.000654304-4.855e-14im
#
# ...
#
# [:, :, 98] =
#  0.000301709+2.75668e-14im  0.000165411-8.99039e-15im
#
# [:, :, 99] =
#  -0.00063169-6.99755e-14im  4.09588e-5+2.44177e-14im
#
# [:, :, 100] =
#  0.000651138+6.83059e-14im  -0.000223626-2.20093e-14im

# %%
# Put in Psi functions
Psi(x) = [x; x.^3]

# Model reduction Parameters
n = 3
p = 500
ty = "bin"

xspec_est = "SP"

nfft = 0

@time h_pack_sp = get_wf(X, Psi;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol);

h_wf_sp                              = h_pack_sp[1][1][1,:,1]
# Out:
# Number of CKMS iterations: 6801
# errK errR : 7.188946213993904e-11 4.083057817338725e-14
# 102.830857 seconds (594.01 M allocations: 87.953 GiB, 10.06% gc time)
# 2-element Array{Complex{Float64},1}:
#     1.011961892599562 + 6.73071123280616e-15im
#  -0.01045459060348742 - 1.943334695292819e-15im

# %%
h_wf_dm                              = h_pack_dm[1][1]
z_spect_pred_minus_num_fft_dm        = h_pack_dm[1][4]
z_spect_pred_plus_num_fft_dm         = h_pack_dm[1][5]
S_sigpred_overS_plus_fft_num_dm      = h_pack_dm[1][6]
S_sigpred_overS_plus_plus_num_fft_dm = h_pack_dm[1][7]
H_num_dm                             = h_pack_dm[1][8];

h_wf_sp                              = h_pack_sp[1][1]
z_spect_pred_minus_num_fft_sp        = h_pack_sp[1][4]
z_spect_pred_plus_num_fft_sp         = h_pack_sp[1][5]
S_sigpred_overS_plus_fft_num_sp      = h_pack_sp[1][6]
S_sigpred_overS_plus_plus_num_fft_sp = h_pack_sp[1][7]
H_num_sp                             = h_pack_sp[1][8];

nfft_sp = size(H_num_sp,3)
nfft_dm = size(H_num_dm,3)
T_sp = 2π*(0:nfft_sp-1)/nfft_sp
T_dm = 2π*(0:nfft_dm-1)/nfft_dm
# Out:
# 0.0:9.587379924285257e-5:6.2830894333803435

# %%
plot(T_sp[1:100:end],real(H_num_sp[1,1,1:100:end]'),label = "sp real")
plot(T_dm,real(H_num_dm[1,1,:]'),label = "dm real")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000018E2F88>

# %%
semilogx(T_sp[1:100:end],
    reverse([real(S_sigpred_overS_plus_plus_num_fft_sp[1,1,
                1:100:end]) imag(S_sigpred_overS_plus_plus_num_fft_sp[1,1,
                    1:100:end])],dims = 1),
    ":",
    label = "sp")
semilogx(T_dm[1:100:end],
    reverse([real(S_sigpred_overS_plus_plus_num_fft_dm[1,1,
                1:100:end]) imag(S_sigpred_overS_plus_plus_num_fft_dm[1,1,
                    1:100:end])],dims = 1),
    label = "dm")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# sys:1: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# PyObject <matplotlib.legend.Legend object at 0x0000000001EDA648>

# %%
semilogx(T_sp[1:100:end],
    [real(S_sigpred_overS_plus_plus_num_fft_sp[1,1,
                1:100:end]) imag(S_sigpred_overS_plus_plus_num_fft_sp[1,1,
                    1:100:end])],
    ":",
    label = "sp")
semilogx(T_dm[1:100:end],
    [real(S_sigpred_overS_plus_plus_num_fft_dm[1,1,
                1:100:end]) imag(S_sigpred_overS_plus_plus_num_fft_dm[1,1,
                    1:100:end])],
    label = "dm")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# sys:1: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# PyObject <matplotlib.legend.Legend object at 0x000000004ACABC88>

# %%
semilogy(T_dm,z_spect_pred_minus_num_fft_dm[1,1,:])
semilogy(T_sp[1:100:end],z_spect_pred_minus_num_fft_sp[1,1,1:100:end])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000627232C8>

# %% [markdown]
# ### Shifted Double Well

# %% [markdown]
# $V(x) = 1/4((x-2)^2 - 1)$

# %%
V_prime = x -> -(x.^3 - 6x.^2 + 11 .*x .- 6)

V_prime([1 2 3])
# Out:
# 1×3 Array{Int64,2}:
#  0  0  0

# %%
# Model run Parameters
steps = 10^7 + 1
scheme = "FE"
t_start = 0
t_stop = 10^5
discard = 100000
sig_init = [1.5]
sigma = [.5]
SM1 = false
Obs_noise = false
d = 1
# e = randn(d,steps + discard)

dt = (t_stop - t_start)/(steps - 1)

# Get full model run
Random.seed!(2016)
X = DataGen_DWOL(
    steps;
    scheme, t_start, t_stop, discard, 
    sig_init , sigma, V_prime,
    SM1, Obs_noise, d
    )
# Out:
# 1×10000001 Array{Float64,2}:
#  3.09368  2.99808  3.01524  3.01428  …  1.36308  1.3479  1.31585  1.33509

# %%
plot(X[1,1:100000])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000061AE0C48>

# %%
m = mean(X[:])

X_c = X .- m
# Out:
# 1×10000001 Array{Float64,2}:
#  1.10815  1.01255  1.02971  1.02875  …  -0.637629  -0.669677  -0.650443

# %%
# Put in Psi functions
Psi(x) = [x; x.^3]

# Model reduction Parameters
M_out = 100
n = 3
p = 500
par = 55
ty = "bin"
xspec_est = "DM"
rl = false
Preds = true
PI = false
rtol = 1e-6

nfft = 2^16

@time h_pack_dm = get_wf(X_c, Psi;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol);

h_wf_dm = h_pack_dm[1][1]
# Out:
# Number of CKMS iterations: 229
# errK errR : 5.527972674114068e-11 1.5821819974999246e-14
#  26.530416 seconds (32.92 M allocations: 14.268 GiB, 5.42% gc time)
# 1×2×100 Array{Complex{Float64},3}:
# [:, :, 1] =
#  1.01007-4.01005e-14im  -0.0100435+8.84311e-15im
#
# [:, :, 2] =
#  -0.00117868+3.44436e-14im  0.000304016-7.7716e-15im
#
# [:, :, 3] =
#  0.000972014+5.37687e-14im  -0.000220177-1.24893e-14im
#
# ...
#
# [:, :, 98] =
#  -1.79223e-7+4.38881e-15im  4.4356e-8-1.48927e-15im
#
# [:, :, 99] =
#  -4.80192e-7+7.18793e-15im  1.18287e-7-1.71307e-15im
#
# [:, :, 100] =
#  -8.7183e-7-1.51179e-14im  2.13738e-7+4.05233e-15im

# %% [markdown]
# ### Uneven Double well

# %% [markdown]
# $V(x) = \frac{1}{10}x(x+1)(x-4)^2$
#
# $V'(x) = \frac{1}{10}(4x^3 - 21x^2 + 16x + 16)$
#
# The left well is a little low then the right.

# %%
V       = x ->  1/10*x*(x+1)*(x-4)^2
V_prime = x -> -(4x.^3 - 21x.^2 + 16x .+ 16)/10

xx = -1.5:0.01:5
plot(xx,V.(xx))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000005D87E288>

# %%
# Model run Parameters
steps = 10^7 + 1
scheme = "FE"
t_start = 0
t_stop = 10^5
discard = 100000
sig_init = [1.5]
sigma = [2]
SM1 = false
Obs_noise = false
d = 1
# e = randn(d,steps + discard)

dt = (t_stop - t_start)/(steps - 1)

# Get full model run
Random.seed!(2018)
X = DataGen_DWOL(
    steps;
    scheme, t_start, t_stop, discard, 
    sig_init , sigma, V_prime,
    SM1, Obs_noise, d
    )
# Out:
# 1×10000001 Array{Float64,2}:
#  3.53097  3.76596  3.54371  3.79429  …  -0.66387  -0.672487  -0.575031

# %%
### This is how we set up the signals and 
### predictors They have to me off set so 
### that pred is one index behind signal
### i.e. pre(n) = psi(sig(n-1))
X_sig = X[:,2:end];

Psi(x) = [x; x.^2; x.^3]
X_pred = get_pred(X,Psi) # Notice it is just 
                         # X get_pred assigns
                         # psi straight across
# Out:
# 3×10000001 Array{Float64,2}:
#   3.53097   3.76596   3.54371   3.79429  …  -0.66387   -0.672487  -0.575031
#  12.4677   14.1825   12.5579   14.3966       0.440724   0.452239   0.33066
#  44.0231   53.4107   44.5017   54.6249      -0.292583  -0.304125  -0.19014

# %%
plot(X[1,1:100000])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000005D8CAE88>

# %%
σ = sigma[1]
O = emp_pdf(X[1,:])
p_ana(x) = exp(-V(x)*2/σ^2)
α = maximum(O[1])/p_ana(-0.554)
plot(O[2],p_ana.(O[2])*α)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000003DB37E48>

# %%
m = mean(X[:])
# Out:
# 1.5086913695581312

# %%
# ## Redone model with centered wells
# V_c       = x -> V(x .+ m)
# V_c_prime = x -> V_prime(x .+ m)

# # rerun centered model to check
# Random.seed!(2014)
# X_c = DataGen_DWOL(
#     steps;
#     scheme, t_start, t_stop, discard, 
#     sig_init , sigma, V_prime = V_c_prime,
#     SM1, Obs_noise, d
#     )

# m_c = mean(X_c[:])

X_c = X .- m
# Out:
# 1×10000001 Array{Float64,2}:
#  2.02228  2.25727  2.03502  2.2856  2.28677  …  -2.17256  -2.18118  -2.08372

# %%
# Put in Psi functions
Psi(x) = [x; x.^2; x.^3]

# Model reduction Parameters
M_out = 100
n = 3
p = 500
par = 55
ty = "bin"
xspec_est = "DM"
rl = false
Preds = true
PI = false
rtol = 1e-6

nfft = 2^16

@time h_pack_dm = get_wf(X_c, Psi;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol);

h_wf_dm = h_pack_dm[1][1]
# Out:
# Number of CKMS iterations: 225
# errK errR : 9.615384420112286e-11 1.08569807547072e-13
#  51.455326 seconds (42.96 M allocations: 26.412 GiB, 8.94% gc time)
# 1×3×100 Array{Complex{Float64},3}:
# [:, :, 1] =
#  1.01998-5.38923e-15im  0.00282119-2.10426e-16im  -0.00400158+1.53068e-16im
#
# [:, :, 2] =
#  0.000392244-1.24015e-14im  …  -4.061e-6+6.72822e-16im
#
# [:, :, 3] =
#  -0.000405075+3.19387e-14im  …  5.70645e-6-1.40352e-15im
#
# ...
#
# [:, :, 98] =
#  1.00543e-9+1.01893e-15im  …  -1.15003e-10-4.24527e-17im
#
# [:, :, 99] =
#  1.5639e-7+1.15328e-15im  4.7929e-9+3.54468e-17im  -6.89812e-9-6.48792e-17im
#
# [:, :, 100] =
#  1.29151e-7+5.01959e-16im  4.12668e-9+3.75403e-18im  -6.08368e-9-2.0683e-17im

# %% [markdown]
# Analytic solution:

# %%
h_ana = [1-dt*(6m^2/5-21m/5+8/5) -dt*(6m/5-21/10) -dt*2/5]
# Out:
# 1×3 Array{Float64,2}:
#  1.02005  0.0028957  -0.004

# %% [markdown]
# ## Analyze Wiener Filter

# %%
plot_WF(h_wf_dm, rl = false)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Elements of h_wf over lags')

# %% [markdown]
# ## Analyze One step prediction error

# %%
### This is how we set up the signals and 
### predictors They have to me off set so 
### that pred is one index behind signal
### i.e. pre(n) = psi(sig(n-1))
X_c_sig = X_c[:,2:end];

Psi(x) = [x; x.^2; x.^3]
X_c_pred = get_pred(X_c,Psi) # Notice it is just 
                         # X get_pred assigns
                         # psi straight across








X_c_hat = one_step_pred(X_c_sig, h_wf_dm, X_c_pred)
# Out:
# 1×10000000 Array{Complex{Float64},2}:
#  2.25727+0.0im  2.03502+0.0im  2.2856+0.0im  …  -2.16951+3.05467e-15im

# %%
wind = (1:100) .+ 2400
plot([X_c_sig[1,wind] X_c_hat[1,wind.+1]])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000003D4DFBC8>
#  PyObject <matplotlib.lines.Line2D object at 0x000000003D4EBBC8>

# %%
X_c_err = X_c_sig - X_c_hat
# Out:
# 1×10000000 Array{Complex{Float64},2}:
#  0.0-0.0im  0.0-0.0im  0.0-0.0im  0.0-0.0im  …  0.0857871-3.05467e-15im

# %%
lags = -100:100
C1 = my_crosscov(X_c_pred[1,1:end-1],X_c_err[:],lags);
C2 = my_crosscov(X_c_pred[2,1:end-1],X_c_err[:],lags);
C3 = my_crosscov(X_c_pred[3,1:end-1],X_c_err[:],lags);

plot(dt*lags,[C1 C2 C3])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 3-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000045455DC8>
#  PyObject <matplotlib.lines.Line2D object at 0x000000004545FDC8>
#  PyObject <matplotlib.lines.Line2D object at 0x000000004545FF88>

# %% [markdown]
# ## Analyze Reduced Model Run

# %%
X_rm = redmodrun(X, h_wf, Psi)
# Out:
# UndefVarError: h_wf not defined
#
# Stacktrace:
#  [1] top-level scope at In[103]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [3] execute_code(::String, ::String) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [5] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [6] invokelatest at .\essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at C:\Users\jared\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at .\task.jl:356

# %% [markdown]
# # Trick (model mismatch)

# %%
X = X_c

n = 3
p = 500
ty = "bin"

xspec_est = "SP"

# Put in Psi functions
Psi_cos(x) = [x; cos.(x)]
@time h_wf_cos = get_wf(X, Psi_cos;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol)[1][1];

h_wf_cos[1,:,1]
# Out:
# Number of CKMS iterations: 167
# errK errR : 9.374791703147495e-11 9.052200030230077e-14
#  18.580232 seconds (33.77 M allocations: 11.036 GiB, 10.56% gc time)
# 2-element Array{Complex{Float64},1}:
#    1.4200064920438717 + 3.7886651260760325e-15im
#  -0.28203121856677527 - 2.2236580681601625e-15im

# %%
Psi_sin(x) = [x; sin.(x)]
@time h_wf_sin = get_wf(X, Psi_sin;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol)[1][1];

h_wf_sin[1,:,1]
# Out:
# Number of CKMS iterations: 159
# errK errR : 9.977222842607679e-11 2.5189595213880066e-14
#  18.216148 seconds (33.77 M allocations: 11.036 GiB, 9.95% gc time)
# 2-element Array{Complex{Float64},1}:
#  1.4699117793539127 + 7.952877570739135e-15im
#  0.6602675040114987 + 1.7234462890691997e-14im

# %%
Psi_exp(x) = [x; exp.(x); exp.(-x)]
@time h_wf_exp = get_wf(X, Psi_exp;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol)[1][1];

h_wf_exp[1,:,1]
# Out:
# Number of CKMS iterations: 210
# errK errR : 9.744573901695542e-11 1.6730529367908863e-13
#  39.719329 seconds (54.19 M allocations: 22.460 GiB, 8.94% gc time)
# 3-element Array{Complex{Float64},1}:
#    1.8625975815229747 + 1.203132601393084e-15im
#  -0.03235890635202794 + 3.0713091555035394e-16im
#   0.09301439578288606 - 5.622628435351296e-17im

# %%
Psi_expi(x) = [x; exp.(im*x); exp.(-im*x)]
@time h_wf_expi = get_wf(X, Psi_expi;
    M_out, n, p, par, ty, nfft, rl = false, xspec_est, Preds, PI, rtol)[1][1];

h_wf_expi[1,:,1]
# Out:
# Number of CKMS iterations: 182
# errK errR : 5.837730128787683e-11 1.0405275456426972e-13
#  40.452403 seconds (64.22 M allocations: 23.502 GiB, 9.14% gc time)
# 3-element Array{Complex{Float64},1}:
#    1.4199609381957052 + 8.109583570459419e-15im
#  -0.14100796253004932 - 0.7687207083531645im
#  -0.14100796253006576 + 0.7687207083531642im

# %%
fun(x) = h_ana*Psi(x)
fun_c(x) = h_wf_dm[:,:,1]*Psi(x)
fun_cos(x) = h_wf_cos[:,:,1]*Psi_cos(x)
fun_sin(x) = h_wf_sin[:,:,1]*Psi_sin(x)
fun_exp(x) = h_wf_exp[:,:,1]*Psi_exp(x)
fun_expi(x) = h_wf_expi[:,:,1]*Psi_expi(x)
# Out:
# fun_expi (generic function with 1 method)

# %%
xx = -5:0.01:5
plot(xx,fun.(xx),label = "analytic")
plot(xx,fun_c.(xx),label = "cube")
plot(xx,fun_cos.(xx),label = "cos")
plot(xx,fun_sin.(xx),label = "sin")
plot(xx,fun_exp.(xx),label = "exp")
plot(xx,real(fun_expi.(xx)),label = "expi real")
plot(xx,imag(fun_expi.(xx)),label = "expi imag")
println(h_wf_dm[:,:,1])
println(h_wf_cos[:,:,1])
println(h_wf_sin[:,:,1])
println(h_wf_exp[:,:,1])
println(h_wf_expi[:,:,1])
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# Complex{Float64}[1.0199817374095421 - 5.3892299298299715e-15im 0.002821185370935498 - 2.1042636797857449e-16im -0.004001577635135993 + 1.5306827048213108e-16im]
# Complex{Float64}[1.4200064920438717 + 3.7886651260760325e-15im -0.28203121856677527 - 2.2236580681601625e-15im]
# Complex{Float64}[1.4699117793539127 + 7.952877570739135e-15im 0.6602675040114987 + 1.7234462890691997e-14im]
# Complex{Float64}[1.8625975815229747 + 1.203132601393084e-15im -0.03235890635202794 + 3.0713091555035394e-16im 0.09301439578288606 - 5.622628435351296e-17im]
# Complex{Float64}[1.4199609381957052 + 8.109583570459419e-15im -0.14100796253004932 - 0.7687207083531645im -0.14100796253006576 + 0.7687207083531642im]
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PyObject <matplotlib.legend.Legend object at 0x000000005C46BF08>

# %%
X = X_c

n = 3
p = 500
ty = "bin"

xspec_est = "DM"

# Put in Psi functions
Psi_cos(x) = [x; cos.(x)]
@time h_wf_cos = get_wf(X, Psi_cos;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol)[1][1];

h_wf_cos[1,:,1]
# Out:
# Number of CKMS iterations: 167
# errK errR : 9.374791703147495e-11 9.052200030230077e-14
#  26.201684 seconds (32.91 M allocations: 14.266 GiB, 10.03% gc time)
# 2-element Array{Complex{Float64},1}:
#      0.989244824494796 - 3.660492735074045e-15im
#  -0.010136530534427885 + 9.37726626911212e-16im

# %%
Psi_sin(x) = [x; sin.(x)]
@time h_wf_sin = get_wf(X, Psi_sin;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol)[1][1];

h_wf_sin[1,:,1]
# Out:
# Number of CKMS iterations: 159
# errK errR : 9.977222842607679e-11 2.5189595213880066e-14
#  26.159540 seconds (32.91 M allocations: 14.265 GiB, 9.78% gc time)
# 2-element Array{Complex{Float64},1}:
#   0.9823560537278524 - 4.741275629227932e-15im
#  0.04785540037246222 - 6.070999726682512e-15im

# %%
Psi_exp(x) = [x; exp.(x); exp.(-x)]
@time h_wf_exp = get_wf(X, Psi_exp;
    M_out, n, p, par, ty, nfft, rl, xspec_est, Preds, PI, rtol)[1][1];

h_wf_exp[1,:,1]
# Out:
# Number of CKMS iterations: 210
# errK errR : 9.744573901695542e-11 1.6730529367908863e-13
#  52.214249 seconds (52.95 M allocations: 27.304 GiB, 9.34% gc time)
# 3-element Array{Complex{Float64},1}:
#     1.0234639982393714 - 7.209080560029547e-15im
#  -0.004547171486077173 + 2.8639038884946637e-16im
#   0.007291893679170679 - 5.783046485552216e-16im

# %%
Psi_expi(x) = [x; exp.(im*x); exp.(-im*x)]
@time h_wf_expi = get_wf(X, Psi_expi;
    M_out, n, p, par, ty, nfft, rl = false, xspec_est, Preds, PI, rtol)[1][1];

h_wf_expi[1,:,1]
# Out:
# Number of CKMS iterations: 182
# errK errR : 5.837730128787683e-11 1.0405275456426972e-13
#  52.673898 seconds (62.97 M allocations: 28.347 GiB, 9.65% gc time)
# 3-element Array{Complex{Float64},1}:
#      0.9892164118508561 + 2.9800184683842296e-16im
#  -0.0050741214373319545 - 0.6266933845334508im
#   -0.005074121437333562 + 0.6266933845334537im

# %%
fun(x) = h_ana*Psi(x)
fun_c(x) = h_wf_dm[:,:,1]*Psi(x)
fun_cos(x) = h_wf_cos[:,:,1]*Psi_cos(x)
fun_sin(x) = h_wf_sin[:,:,1]*Psi_sin(x)
fun_exp(x) = h_wf_exp[:,:,1]*Psi_exp(x)
fun_expi(x) = h_wf_expi[:,:,1]*Psi_expi(x)
# Out:
# fun_expi (generic function with 1 method)

# %%
xx = -5:0.01:5
plot(xx,fun.(xx),label = "analytic")
plot(xx,fun_c.(xx),label = "cube")
plot(xx,fun_cos.(xx),label = "cos")
plot(xx,fun_sin.(xx),label = "sin")
plot(xx,fun_exp.(xx),label = "exp")
plot(xx,real(fun_expi.(xx)),label = "expi real")
plot(xx,imag(fun_expi.(xx)),label = "expi imag")
println(h_wf_dm[:,:,1])
println(h_wf_cos[:,:,1])
println(h_wf_sin[:,:,1])
println(h_wf_exp[:,:,1])
println(h_wf_expi[:,:,1])
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# Complex{Float64}[1.0199817374095421 - 5.3892299298299715e-15im 0.002821185370935498 - 2.1042636797857449e-16im -0.004001577635135993 + 1.5306827048213108e-16im]
# Complex{Float64}[0.989244824494796 - 3.660492735074045e-15im -0.010136530534427885 + 9.37726626911212e-16im]
# Complex{Float64}[0.9823560537278524 - 4.741275629227932e-15im 0.04785540037246222 - 6.070999726682512e-15im]
# Complex{Float64}[1.0234639982393714 - 7.209080560029547e-15im -0.004547171486077173 + 2.8639038884946637e-16im 0.007291893679170679 - 5.783046485552216e-16im]
# Complex{Float64}[0.9892164118508561 + 2.9800184683842296e-16im -0.0050741214373319545 - 0.6266933845334508im -0.005074121437333562 + 0.6266933845334537im]
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PyObject <matplotlib.legend.Legend object at 0x0000000047B88848>

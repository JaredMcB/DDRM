# %% [markdown]
# # Tester: Nonlinear Langevin
# ## Double-welled overdamped Langevin (DWOL)

# %% [markdown]
# Here we take for out potential the function $$V(x) = 1/4(x^2-1)^2$$ and so the (overdamped, stochastic) Langenvin equation is $$dX_t = -V'(X_t)dt + \sigma dW_t = -X_t(X_t^2-1) + \sigma dW_t$$
# We solve this numerically in various ways to get an approximate solution if to the equation. For instance we will often use Euler-Maruyama which soluction takes the form
# $$Y_{n+1} = Y_{n} + \Delta t\big(-Y_n(Y_n^2-1)\big) + \sigma \sqrt{\Delta t}v_n$$
# where $Y_n \approx X_{\Delta t n}$ and $v_n \sim N(0,1)$ for all $n = 0,1,2,\dots$ are i.i.d.
#
# The goal here is to reproduce the statisical and dynamical information (?). Of a realization of $Y = (Y_n;\;n=o,1,2,\dots)$ using a reduced model. We will compare the autocavariances as well as the pdf the $Y_n$.
#
# So, first we run the full model. To do this I use the function `DataGen_DWOL` found in th file `DataGen.jl` found in the current folder (`Examples\Nonlinear Langevin`).

# %%
using PyPlot
using Random

# Get software to generate model
include("../Nonlinear Langevin/DataGen.jl")

# Get model reduction software being tested
include("../../Tools/Model_Reduction_Dev.jl")

# Get tester tools
include("testertools.jl")
# Out:
# causal_test (generic function with 1 method)

# %%
# Model run Parameters
steps = 10^6 + 1
scheme = "FE"
t_start = 0
t_stop = 10^4
discard = 100000
sig_init = [1.5]
sigma = [.5]
V_prime = x -> -x.*(x.^2 .- 1)
SM1 = false
Obs_noise = false
d = 1
# e = randn(d,steps + discard)

dt = (t_stop - t_start)/(steps - 1)


# Get full model run
Random.seed!(2015)
X = DataGen_DWOL(
    steps;
    scheme, t_start, t_stop, discard, 
    sig_init , sigma, V_prime,
    SM1, Obs_noise, d
    )
# Out:
# 1×1000001 Array{Float64,2}:
#  -0.994938  -0.975163  -0.975252  -1.02331  …  0.703714  0.687602  0.704474

# %%
plot(X[1,1:10:end])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000611ADF48>

# %%
lags = -50:50

A = my_autocor(X[1,:],lags)

plot(dt*lags,lam.*A)
plot(dt*lags,A)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000002620F88>

# %%
lam = _window(50)
# Out:
# 101-element Array{Float64,1}:
#  -9.818186930595453e-91
#   1.6000000000000003e-5
#   0.00012800000000000002
#   0.000432
#   0.0010240000000000002
#   0.0020000000000000005
#   0.003456
#   0.0054880000000000016
#   0.008192000000000001
#   0.011663999999999999
#   0.016000000000000004
#   0.021296
#   0.027648
#   ⋮
#   0.021296
#   0.016000000000000004
#   0.011663999999999999
#   0.008192000000000001
#   0.0054880000000000016
#   0.003456
#   0.0020000000000000005
#   0.0010240000000000002
#   0.000432
#   0.00012800000000000002
#   1.6000000000000003e-5
#  -9.818186930595453e-91

# %%
L    = 5000
Nex  = 50000
win  = "Par"

nfft = 0
n    = 2
p    = 500
ty   = "bin"


spect_D  = z_crossspect_fft_old(X,X;
    L, Nex, win);
F_D = 2π*(0:Nex-1)/Nex

spect_SP = z_crossspect_fft(X, X;
    nfft, n, p, ty) ;
N = size(spect_SP,3)
F_SP = 2π*(0:N-1)/N;

μ = _smoother(n,p;ty)
println("sum of μ: ",sum(μ))

spect_ana(θ) = 0

semilogy(F_SP,spect_SP[1,1,:] - spect_ana.(F_SP),label = "Smoother Periodogram")
semilogy(F_D,spect_D[1,1,:] - spect_ana.(F_D),label = "Direct Estimator")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# sum of μ: 1.0
# C:\Users\JaredMcBride\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\JaredMcBride\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000659E3FC8>

# %%
# Put in Psi functions
Psi(x) = [x; x.^3]
# Out:
# Psi (generic function with 1 method)

# %%
# Model reduction Parameters
M_out = 100
n = 2
p = 500
par = 5000
ty = "bin"
rl = true
Preds = true
PI = false
rtol = 1e-6

nfft = 50000

@time h_wf, pred = get_wf(X, Psi;
    M_out, n, p, par, ty, nfft, rl, Preds, PI, rtol);

X_sig = X[:,2:end];
# Out:
# Number of CKMS iterations: 4089
# errK errR : 6.717282216075385e-11 1.1555219410908577e-13
#  15.169182 seconds (5.98 M allocations: 14.377 GiB, 18.88% gc time)

# %%
pred
# Out:
# 2×1000000 Array{Complex{Float64},2}:
#  -0.994938+0.0im  -0.975163+0.0im  …  0.703714+0.0im  0.687602+0.0im
#   -0.98489+0.0im  -0.927323+0.0im     0.348488+0.0im  0.325097+0.0im

# %% [markdown]
# ## Analyze Wiener Filter

# %%
h_wf
# Out:
# 1×2×100 Array{Float64,3}:
# [:, :, 1] =
#  1.01316  -0.0107767
#
# [:, :, 2] =
#  -0.00614669  0.0014868
#
# [:, :, 3] =
#  0.00276786  -0.000444076
#
# ...
#
# [:, :, 98] =
#  0.00172214  -0.000271382
#
# [:, :, 99] =
#  0.00129058  -0.000175618
#
# [:, :, 100] =
#  -0.00617988  0.00166548

# %%
plot_WF(h_wf, rl = false)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Elements of h_wf over lags')

# %% [markdown]
# ## Analyze One step prediction error

# %%
X_hat = one_step_pred(X_sig, h_wf, pred)
# Out:
# 1×1000000 Array{Complex{Float64},2}:
#  1.02916+0.0im  1.03707+0.0im  1.0349+0.0im  …  0.907468+0.0im  0.89788+0.0im

# %%
wind = (1:100) .+ 24000
plot([X_sig[1,wind] X_hat[1,wind.+1]])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\JaredMcBride\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000001771ADC8>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000017726988>

# %%
X_err = X_sig - X_hat
# Out:
# 1×1000000 Array{Complex{Float64},2}:
#  0.0-0.0im  0.0-0.0im  0.0-0.0im  …  -0.00980779-0.0im  0.0075946-0.0im

# %%
lags = -100:100
C1 = my_crosscov(pred[1,:],X_err[:],lags);
C2 = my_crosscov(pred[2,:],X_err[:],lags);

plot(dt*lags,[C1 C2])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\JaredMcBride\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000059789748>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000059795408>

# %% [markdown]
# ## Analyze Reduced Model Run

# %%
X_rm = redmodrun(X, h_wf, Psi)
# Out:
# reduced model blewup at step 4768

# %%
t_stop = 10^4

Random.seed!(2015)
X = DataGen_DWOL(
    steps;
    scheme, t_start, t_stop, discard, 
    sig_init , sigma, V_prime,
    SM1, Obs_noise, d
    )

# Model reduction Parameters
M_out = 100
n = 2
p = 500
par = 55
ty = "bin"
rl = true
Preds = true
PI = false
rtol = 1e-6

nfft = 1024

@time h_wf, pred = get_wf(X, Psi;
    M_out, n, p, par, ty, nfft, rl, Preds, PI, rtol);

X_sig = X[:,2:end];

h_wf
# Out:
# Number of CKMS iterations: 229
# errK errR : 8.403373955225124e-11 3.3295025615166646e-14
#   2.701731 seconds (3.06 M allocations: 1.420 GiB, 11.31% gc time)
# 1×2×100 Array{Float64,3}:
# [:, :, 1] =
#  1.01214  -0.0104821
#
# [:, :, 2] =
#  -0.00577268  0.00140345
#
# [:, :, 3] =
#  0.00251975  -0.0003896
#
# ...
#
# [:, :, 98] =
#  1.9403e-6  -4.75491e-7
#
# [:, :, 99] =
#  -4.8148e-6  1.1799e-6
#
# [:, :, 100] =
#  -7.86683e-6  1.92763e-6

# %%
t_stop = 10^4

Random.seed!(2015)
X = DataGen_DWOL(
    steps;
    scheme, t_start, t_stop, discard, 
    sig_init , sigma, V_prime,
    SM1, Obs_noise, d
    )

# Model reduction Parameters
M_out = 100
n = 2
p = 500
par = 5000
ty = "bin"
rl = true
Preds = true
PI = false
rtol = 1e-6

nfft = par*10

@time h_wf, pred = get_wf(X, Psi;
    M_out, n, p, par, ty, nfft, rl, Preds, PI, rtol);

X_sig = X[:,2:end];

h_wf
# Out:
# Number of CKMS iterations: 4089
# errK errR : 6.717282216075385e-11 1.1555219410908577e-13
#  15.375801 seconds (5.98 M allocations: 14.377 GiB, 21.24% gc time)
# 1×2×100 Array{Float64,3}:
# [:, :, 1] =
#  1.01316  -0.0107767
#
# [:, :, 2] =
#  -0.00614669  0.0014868
#
# [:, :, 3] =
#  0.00276786  -0.000444076
#
# ...
#
# [:, :, 98] =
#  0.00172214  -0.000271382
#
# [:, :, 99] =
#  0.00129058  -0.000175618
#
# [:, :, 100] =
#  -0.00617988  0.00166548

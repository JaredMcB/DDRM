# %%
include("..\\Model_Reduction_Dev.jl")
include("AnalysisToolbox_scratch_ckms.jl")


using PyPlot
using JLD

function visual_test_ckms(P,l,nfft;semilog = false)
    d  = size(P,1)
    lp = size(P,3)
    ll = size(l,3)
    S_fun(z)    = P[:,:,1] + sum(P[:,:,i]*z^(-i+1) + P[:,:,i]'*z^(i-1) for i = 2:lp)
    S_fun_minus(z) = sum(l[:,:,i]*z^(-i+1) for i = 1:ll)
    S_fun_plus(z) = sum(l[:,:,i]'*z^(i-1) for i = 1:ll)

    Θ = 2π*(0:nfft-1)/nfft
    Z = exp.(im*Θ)
    S = complex(zeros(d,d,nfft))
    S_l = complex(zeros(d,d,nfft))
    for i = 1:nfft
        S[:,:,i] = S_fun(Z[i])
        S_l[:,:,i] = S_fun_minus(Z[i])*S_fun_plus(Z[i])
    end


    for i = 1:d
        for j = i:d
            semilog ? loglog(Θ,real(S[i,j,:]), label = "S ($i,$j)") :
                      plot(Θ,real(S[i,j,:]), label = "S ($i,$j)")
            
            semilog ? loglog(Θ,real(S_l[i,j,:]), label = "S_l ($i,$j)") :
                      plot(Θ,real(S_l[i,j,:]), label = "S_l ($i,$j)")
        end
    end
    legend()
end
# Out:
# visual_test_ckms (generic function with 1 method)

# %% [markdown]
# ## Real Scalar process

# %% [markdown]
# First we start with the spectrum we are approximating.

# %%
P = zeros(1,1,2)
P[1,1,1] = 10
P[1,1,2] = 3

L = spectfact_matrix_CKMS(P)
# Out:
# 1×1×2 Array{Complex{Float64},3}:
# [:, :, 1] =
#  3.000000000000001 + 0.0im
#
# [:, :, 2] =
#  0.9999999999999998 + 0.0im

# %%
d, d1, m = size(L)

steps = 10^6

u = randn(d, 2*steps) 
X = zeros(d, 2*steps)
for n = m:2*steps
    X[:,n] = sum(L[:,:,j]*u[:,n-j+1] for j = 1:m)
end
X = X[:,steps+1:end]
# Out:
# 1×1000000 Array{Float64,2}:
#  -2.35895  0.225186  -2.93367  -0.47043  …  2.69044  2.11819  -4.40254

# %%
P_autocov = matrix_autocov_seq(X,
       L = 1500,
       steps = steps,
       nu = d,
       win = "Par"
       )
# Out:
# 1×1×1501 Array{Complex,3}:
# [:, :, 1] =
#  10.00535621386773 + 0.0im
#
# [:, :, 2] =
#  2.9959034770197737 + 0.0im
#
# [:, :, 3] =
#  -0.001082956196737757 + 0.0im
#
# ...
#
# [:, :, 1499] =
#  6.911000897144273e-11 + 0.0im
#
# [:, :, 1500] =
#  1.5772240244317133e-11 + 0.0im
#
# [:, :, 1501] =
#  0.0 + 0.0im

# %%
z_spect_X = z_spect_scalar(X[1,:], n = 3, p = 1500, ty = "ave")
gap = 100
Θ = 2π*(1:gap:steps)/steps
plot(Θ,z_spect_X[1:gap:steps])
nfft = 1000
visual_test_ckms(P,L,nfft)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000005897FD08>

# %% [markdown]
# Now, how do we plug in the emperical z-spectrum into CKMS?

# %%
P_fft_full = fft(z_spect_X)/steps;

P_fft = reshape(P_fft_full[1:2],1,1,2)
# Out:
# 1×1×2 Array{Complex{Float64},3}:
# [:, :, 1] =
#  9.99852996357537 + 0.0im
#
# [:, :, 2] =
#  3.000265322997333 - 1.88512229954941e-5im

# %%
L_fft = spectfact_matrix_CKMS(P_fft)
# Out:
# 1×1×2 Array{Complex{Float64},3}:
# [:, :, 1] =
#  2.99969117064736 - 4.412084070804417e-24im
#
# [:, :, 2] =
#  1.0001914038203636 - 6.284387932983726e-6im

# %%
L_autocov = spectfact_matrix_CKMS(P_autocov)
# Out:
# 1×1×1501 Array{Complex{Float64},3}:
# [:, :, 1] =
#  3.0011908130795644 + 0.0im
#
# [:, :, 2] =
#  0.9981138017634338 + 0.0im
#
# [:, :, 3] =
#  -0.0002892632911247107 + 0.0im
#
# ...
#
# [:, :, 1499] =
#  2.1279762855021365e-11 + 0.0im
#
# [:, :, 1500] =
#  5.2553273772463056e-12 + 0.0im
#
# [:, :, 1501] =
#  0.0 + 0.0im

# %%
visual_test_ckms(P_autocov,L_autocov,nfft)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000005F8CDBC8>

# %% [markdown]
# ## Real 2×2-matrix process

# %% [markdown]
# First we start with the spectrum we are approximating.

# %%
P = zeros(2,2,2)
P[:,:,1] = [174 17 ; 17 42]
P[:,:,2] = [-2 -4; -79 -8]

l_ana = zeros(2,2,2)
l_ana[:,:,1] = [1 13; 2 1]
l_ana[:,:,2] = [-2 0; -1 -6]

l_num = spectfact_matrix_CKMS(P)
# Out:
# 2×2×2 Array{Complex{Float64},3}:
# [:, :, 1] =
#  13.0+0.0im  1.0+0.0im
#   1.0-0.0im  2.0+0.0im
#
# [:, :, 2] =
#   0.0+0.0im  -2.0+0.0im
#  -6.0+0.0im  -1.0-0.0im

# %%
d, d1, m = size(l_ana)

steps = 10^6

u = randn(d, 2*steps) 
X = zeros(d, 2*steps)
for n = m:2*steps
    X[:,n] = sum(l_ana[:,:,j]*u[:,n-j+1] for j = 1:m)
end
X = X[:,steps+1:end]
# Out:
# 2×1000000 Array{Float64,2}:
#   18.9518  16.2242   12.3995   -2.72405  …   0.701394  8.66532  -26.9872
#  -16.0507  -5.37868  -3.35133  -6.73223     -0.890578  1.2572    -9.03748

# %%
P_autocov = matrix_autocov_seq(X,
       L = 1500,
       steps = steps,
       nu = d,
       win = "Par"
       )

L_autocov = spectfact_matrix_CKMS(P_autocov)
visual_test_ckms(P_autocov,L_autocov,nfft)
visual_test_ckms(P,l_ana,nfft)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000000DB9CC8>

# %% [markdown]
# Now, how do we plug in the emperical z-spectrum into CKMS?

# %% [markdown]
# ## Randomly Generated Autocovariance Matrix

# %% [markdown]
# First we start with the spectrum we are approximating.

# %%
d = 4; m = 10
P = zeros(d,d,m)
for i = 2 : m
    b = randn(d,d)
    P[:,:,i] = b
end
b = randn(d,d)
P[:,:,1] = b*b' + sum(P[:,:,i]*P[:,:,i]' for i = 2:m) + 1e-10*I;

d  = size(P,1)
lp = size(P,3)
S_fun(z)    = P[:,:,1] + sum(P[:,:,i]*z^(-i+1) + P[:,:,i]'*z^(i-1) for i = 2:lp)

Θ = 2π*(0:nfft-1)/nfft
Z = exp.(im*Θ)
detS = zeros(nfft)
for i = 1:nfft
    detS[i] = real(det(S_fun(Z[i])))
end
plot(Θ,detS)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000049E91648>

# %%
l_num, Err = spectfact_matrix_CKMS_SC(P, N_ckms = 1000, update = 100);

d, d1, m = size(l_num)

steps = 10^6

u = randn(d, 2*steps) 
X = zeros(d, 2*steps)
for n = m:2*steps
    X[:,n] = sum(l_num[:,:,j]*u[:,n-j+1] for j = 1:m)
end
X = X[:,steps+1:end]
# Out:
# i : 47
# 4×1000000 Array{Float64,2}:
#  9.83714   4.31204  -6.4398    8.16182   …   6.70294   -2.12062   0.348571
#  5.17016  12.5403    4.20328   0.251246     12.5924    13.5393   -5.63931
#  2.40826  -1.88267  -6.82613   2.14858       2.78836   12.6481   -0.200513
#  1.90651   1.52958   1.71141  -6.30091      -0.280374   1.14925   5.69927

# %%
P_autocov = matrix_autocov_seq(X,
       L = 55,
       steps = steps,
       nu = d,
       win = "Par"
       )

L_autocov = spectfact_matrix_CKMS(P_autocov)
# Out:
# 4×4×56 Array{Complex{Float64},3}:
# [:, :, 1] =
#     6.2364+0.0im   0.400089+0.0im  -0.784664+0.0im  0.329091+0.0im
#   0.400089-0.0im    6.00527+0.0im  -0.117745+0.0im  0.198674+0.0im
#  -0.784664-0.0im  -0.117745-0.0im    5.75521+0.0im  0.246162+0.0im
#   0.329091-0.0im   0.198674-0.0im   0.246162-0.0im   5.80242+0.0im
#
# [:, :, 2] =
#  -0.00159144+0.0im   0.108558+0.0im  0.0222776+0.0im  0.0903168+0.0im
#     0.140677+0.0im   0.112679+0.0im   0.204001+0.0im  -0.188862+0.0im
#  -0.00621135+0.0im   0.141682+0.0im  -0.175185+0.0im  0.0365809+0.0im
#     0.145472+0.0im  -0.136716+0.0im  0.0786438+0.0im  -0.172849+0.0im
#
# [:, :, 3] =
#   0.0572113+0.0im  -0.0292637+0.0im  -0.0281641+0.0im   -0.117286+0.0im
#  -0.0528578+0.0im    0.199244+0.0im   -0.105626+0.0im  -0.0231509+0.0im
#  -0.0262569+0.0im  -0.0763978+0.0im   0.0580818+0.0im   0.0491189+0.0im
#  -0.0917179+0.0im  0.00884308+0.0im   0.0434537+0.0im   0.0479758+0.0im
#
# ...
#
# [:, :, 54] =
#  -1.75908e-7+0.0im  -5.71771e-7+0.0im   1.18584e-6+0.0im  2.37418e-7+0.0im
#  -4.83224e-7+0.0im  -1.58895e-7+0.0im   6.88991e-7+0.0im  4.04595e-8+0.0im
#   9.49098e-7+0.0im   6.28736e-7+0.0im  -9.10292e-7+0.0im  6.37573e-7+0.0im
#   3.15806e-7+0.0im   2.57767e-8+0.0im   7.11038e-7+0.0im  2.14136e-7+0.0im
#
# [:, :, 55] =
#  -4.32077e-8+0.0im   4.76205e-8+0.0im  -3.22419e-8+0.0im  -5.74328e-8+0.0im
#   4.46516e-8+0.0im   1.31252e-7+0.0im   6.96696e-8+0.0im   -4.6303e-8+0.0im
#  -3.93143e-8+0.0im   5.79145e-8+0.0im  -6.61344e-8+0.0im  -3.90555e-9+0.0im
#   -5.7987e-8+0.0im  -3.30975e-8+0.0im  -1.75664e-8+0.0im   4.60174e-8+0.0im
#
# [:, :, 56] =
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im

# %%
visual_test_ckms(P_autocov,L_autocov,nfft)
visual_test_ckms(P,l_num,nfft)
legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000001207188>

# %% [markdown]
# ## From KSE data

# %% [markdown]
# First we start with the spectrum we are approximating.

# %%
data_loc = "C:\\Users\\jared\\Desktop\\Github Repos"*
    "\\DDMR\\Examples\\KSE\\Data\\KSE_sol_Lin.jld"

Data = load(data_loc)

uu = Data["dat_uu"]
vv = Data["dat_vv"]
tt = Data["dat_tt"]

h = Data["h"]
N = Data["N"]
P = Data["P"]
obs_gap = Data["obs_gap"]
Δt = h*obs_gap

t_start = 0
t_stop = 150
ind_start = floor(Int,t_start/Δt)+1
ind_stop =floor(Int,t_stop/Δt)

H1 = imshow(uu[:,ind_start:ind_stop]', extent=[0,21.55,0,150], aspect="auto")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# ┌ Warning: type Dates.DateTime not present in workspace; reconstructing
# └ @ JLD C:\Users\jared\.julia\packages\JLD\jeGJb\src\jld_types.jl:697
# ┌ Warning: type Dates.UTInstant{Dates.Millisecond} not present in workspace; reconstructing
# └ @ JLD C:\Users\jared\.julia\packages\JLD\jeGJb\src\jld_types.jl:697
# ┌ Warning: type Dates.Millisecond not present in workspace; reconstructing
# └ @ JLD C:\Users\jared\.julia\packages\JLD\jeGJb\src\jld_types.jl:697
# PyObject <matplotlib.image.AxesImage object at 0x000000003A13E548>

# %%
X = vv[2:4,:]
d, steps = size(X)

L = 1500

P_autocov = matrix_autocov_seq(X,
       L = L,
       steps = steps,
       nu = d,
       win = "Par"
       )
# Out:
# 3×3×1501 Array{Complex,3}:
# [:, :, 1] =
#   14806.3+0.0im   -231.683+0.0im  -73.5296+0.0im
#  -231.683+0.0im  1.01712e5+0.0im   400.627+0.0im
#  -73.5296+0.0im    400.627+0.0im   67529.5+0.0im
#
# [:, :, 2] =
#   14802.2+0.0192409im   -231.7+4.68992im  -73.5126-4.24218im
#    -231.7+4.68992im    1.017e5+28.8162im   400.382-20.875im
#  -73.5126-4.24218im    400.382-20.875im    67505.5+8.92319im
#
# [:, :, 3] =
#   14789.9+0.0386423im   -231.713+9.3778im   -73.4364-8.48279im
#  -231.713+9.3778im     1.01665e5+57.6109im   399.741-41.7339im
#  -73.4364-8.48279im      399.741-41.7339im   67433.9+17.7978im
#
# ...
#
# [:, :, 1499] =
#   1.77366e-6-1.15843e-7im  -6.00786e-7+2.45031e-6im  1.81091e-6+6.34741e-7im
#  -6.00786e-7+2.45031e-6im   9.40078e-6+2.90375e-6im  5.41921e-6-2.67164e-6im
#   1.81091e-6+6.34741e-7im   5.41921e-6-2.67164e-6im  2.73857e-5+6.61161e-6im
#
# [:, :, 1500] =
#   2.13882e-7-1.48445e-8im  -7.55917e-8+3.05851e-7im  2.29832e-7+7.65524e-8im
#  -7.55917e-8+3.05851e-7im   1.15468e-6+3.45049e-7im  6.63441e-7-3.32984e-7im
#   2.29832e-7+7.65524e-8im   6.63441e-7-3.32984e-7im  3.37816e-6+7.92055e-7im
#
# [:, :, 1501] =
#   0.0-0.0im  -0.0+0.0im  0.0+0.0im
#  -0.0+0.0im   0.0+0.0im  0.0-0.0im
#   0.0+0.0im   0.0-0.0im  0.0+0.0im

# %%
v2 = vv[3,:]
lags = -L:L

A_v2 = my_crosscov(v2,v2,lags)
plot(lags*Δt,A_v2)
plot(Δt*(0:L),P_autocov[2,2,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000001B38988>

# %%
L_autocov = spectfact_matrix_CKMS(P_autocov)
# Out:
# 3×3×1501 Array{Complex{Float64},3}:
# [:, :, 1] =
#   0.305756+3.60893e-16im  0.0429806+7.80899e-5im   0.0323363-0.000282894im
#  0.0429806-7.80899e-5im    0.787147+1.42456e-15im  0.0895795-0.000580327im
#  0.0323363+0.000282894im  0.0895795+0.000580327im   0.649018-6.79867e-15im
#
# [:, :, 2] =
#   0.437436+0.00218062im  0.0536228-0.000692557im  0.0405769+0.00373676im
#  0.0469774-0.00181446im    1.08735+0.00460825im    0.108555+0.000400082im
#  0.0340623+0.00950223im   0.106854+0.00244112im    0.936293+0.00961162im
#
# [:, :, 3] =
#   0.593902+0.00487152im  0.0651628-0.00173175im  0.0495185+0.00876025im
#  0.0498296-0.00410339im    1.43697+0.0103737im    0.128309+0.00146364im
#  0.0342176+0.0209813im    0.124121+0.00452054im    1.27956+0.0214071im
#
# ...
#
# [:, :, 1499] =
#  4.72769e-6-7.03827e-7im  -1.1244e-6+2.55126e-6im  2.20396e-6+5.17295e-7im
#  -3.5011e-6+6.56707e-6im  9.45712e-6+3.2013e-6im   5.77051e-6-4.09468e-6im
#  1.04157e-6+1.36544e-6im  1.86278e-6-3.8926e-6im    3.4372e-5+8.96093e-6im
#
# [:, :, 1500] =
#   6.87431e-7-1.10646e-7im  -1.72607e-7+3.86277e-7im  3.43399e-7+7.02939e-8im
#  -5.34932e-7+1.0021e-6im    1.39847e-6+4.54146e-7im  8.55011e-7-6.24652e-7im
#   1.72317e-7+1.91174e-7im   2.46863e-7-5.843e-7im     5.1628e-6+1.29181e-6im
#
# [:, :, 1501] =
#  0.0+0.0im  0.0+0.0im  0.0-0.0im
#  0.0+0.0im  0.0+0.0im  0.0-0.0im
#  0.0+0.0im  0.0+0.0im  0.0-0.0im

# %%
nfft = 1000
visual_test_ckms(P_autocov[1:1,1:1,:],L_autocov[1:1,1:1,:],nfft, semilog = true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000000190A3C8>

# %%
z_spect_fft = z_crossspect_fft(
    X,
    X,
    nfft = 0,
    n = 3,
    p = 2500,
    win = "Par")

Nfft = size(z_spect_fft,3)
Θ_N = 2π*(0:Nfft-1)/Nfft
d = 2
for i = 1:d
    for j = i:d
        semilogy(Θ_N,z_spect_fft[i,j,:], label = "S_N ($i,$j)")
    end
end

legend(bbox_to_anchor=[1.05,1],loc=2,borderaxespad=0)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\jared\.julia\conda\3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PyObject <matplotlib.legend.Legend object at 0x000000015DE17CC8>

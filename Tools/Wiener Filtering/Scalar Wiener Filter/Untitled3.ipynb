# %%
using FFTW

# %%
Nex = 2^10;
Theta = 2pi*(0:Nex-1)/(Nex-1);
Z = map(th -> exp(im*th),Theta);

# %%
s(z) = 1.1 + 2.3*z -3.4*z^(-1) + 7*z^2 - 6*z^(-2);

# %%
F = fft(s.(Z))/Nex
# Out:
# 1024-element Array{Complex{Float64},1}:
#      1.0999023437500002 + 9.328204441522159e-17im
#      2.3080754670493366 + 0.00708110906361735im
#      6.9935351670190276 + 0.04291233288717188im
#    -0.01801182644721898 - 0.00016578345562973513im
#    -0.01021733124006379 - 0.00012539181326318762im
#   -0.007355374950180786 - 0.00011283888944681072im
#   -0.005812643931326614 - 0.00010700989630706488im
#   -0.004830556600974689 - 0.0001037556857303584im
#   -0.004143994307195739 - 0.00010172935026888225im
#   -0.003634194356261956 - 0.00010037162698309189im
#  -0.0032393216843811822 - 9.941233679989516e-5im
#  -0.0029237404907514926 - 9.87066334546171e-5im
#   -0.002665350640367649 - 9.817067720070646e-5im
#                         ⋮
#    0.002624525341555657 - 9.666699240566912e-5im
#   0.0028748080380583893 - 9.705465452997117e-5im
#   0.0031795574388728343 - 9.757821722741865e-5im
#     0.00355947118128018 - 9.830787201815206e-5im
#    0.004047722895295467 - 9.93660197582457e-5im
# ...

# %%
G = F[13:-1:1]
# Out:
# 13-element Array{Complex{Float64},1}:
#   -0.002665350640367649 - 9.817067720070646e-5im
#  -0.0029237404907514926 - 9.87066334546171e-5im
#  -0.0032393216843811822 - 9.941233679989516e-5im
#   -0.003634194356261956 - 0.00010037162698309189im
#   -0.004143994307195739 - 0.00010172935026888225im
#   -0.004830556600974689 - 0.0001037556857303584im
#   -0.005812643931326614 - 0.00010700989630706488im
#   -0.007355374950180786 - 0.00011283888944681072im
#    -0.01021733124006379 - 0.00012539181326318762im
#    -0.01801182644721898 - 0.00016578345562973513im
#      6.9935351670190276 + 0.04291233288717188im
#      2.3080754670493366 + 0.00708110906361735im
#      1.0999023437500002 + 9.328204441522159e-17im
